# %% [markdown]
# # 03. Web Data

# %% [markdown]
# ## 1. BeautifulSoup for web data

# %% [markdown]
# ***

# %% [markdown]
# ## BeautifulSoup Basic

# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup

# %%
# html 파일 읽기
page = open('../data/03. test_first.html', "r").read()
soup = BeautifulSoup(page, "html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <!-- title : 창 이름 -->
#   <title>
#    Very Simple HTML Code by PinkWink
#   </title>
#  </head>
#  <!-- body : 문서 내용 -->
#  <body>
#   <div>
#    <p class="inner-text first-item" id="first">
#     Happy PinkWink.
#     <!-- PinkWink 글씨에 하이퍼링크가 걸림 -->
#     <a href="http://www.pinkwink.kr" id="pw-link">
#      PinkWink
#     </a>
#    </p>
#    <p class="inner-text second-item">
#     Happy Data Science.
#     <!-- target = "_blink" 속성을 추가하면 새 탭에서 해당 링크가 열림-->
#     <a href="https://www.python.org" id="py-link">
#      Python
#     </a>
#    </p>
#   </div>
#   <p class="outer-text first-item" id="second">
#    <!-- b : 볼드체 -->
#    <b>
#     Data Science is funny.
#    </b>
#   </p>
#   <p class="outer-text">
#    <!-- i : 이탤리체 -->
#    <i>
#     All I need is Love.
#    </i>
#   </p>
#  </body>
# </html>

# %%
# head 태그 확인
soup.head
# Out:
# <head>
# <!-- title : 창 이름 -->
# <title>Very Simple HTML Code by PinkWink</title>
# </head>

# %%
# body 태그 확인
soup.body
# Out:
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <!-- PinkWink 글씨에 하이퍼링크가 걸림 -->
# <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <!-- target = "_blink" 속성을 추가하면 새 탭에서 해당 링크가 열림-->
# <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <!-- b : 볼드체 -->
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <!-- i : 이탤리체 -->
# <i>
#                 All I need is Love.
#             </i>
# </p>
# </body>

# %%
# p 태그 확인
soup.p # 가장 처음으로 나타난 p 태그 출력
# Out:
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <!-- PinkWink 글씨에 하이퍼링크가 걸림 -->
# <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>

# %%
soup.find("p") # 가장 처음으로 나타난 p 태그 출력
# Out:
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <!-- PinkWink 글씨에 하이퍼링크가 걸림 -->
# <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>

# %%
# class에 해당하는 내용 출력
soup.find('p', class_ = "inner-text first-item")
# Out:
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <!-- PinkWink 글씨에 하이퍼링크가 걸림 -->
# <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>

# %%
# 딕셔너리 형태로 써줄 수도 있음
soup.find('p', {"class" : "outer-text first-item"})
# Out:
# <p class="outer-text first-item" id="second">
# <!-- b : 볼드체 -->
# <b>
#                 Data Science is funny.
#             </b>
# </p>

# %%
# 그 안의 텍스트 내용 추출
soup.find('p', {"class" : "outer-text first-item"}).text.strip()
# Out:
# 'Data Science is funny.'

# %%
# 다중 조건
soup.find("p", {"class" : "inner-text first-item",
                "id" : "first"})
# Out:
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <!-- PinkWink 글씨에 하이퍼링크가 걸림 -->
# <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>

# %%
# find_all()

soup.find_all("p") # 모든 p 태그의 내용을 리스트 형태로 출력
# Out:
# [<p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <!-- PinkWink 글씨에 하이퍼링크가 걸림 -->
#  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>,
#  <p class="inner-text second-item">
#                  Happy Data Science.
#                  <!-- target = "_blink" 속성을 추가하면 새 탭에서 해당 링크가 열림-->
#  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>,
#  <p class="outer-text first-item" id="second">
#  <!-- b : 볼드체 -->
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>,
#  <p class="outer-text">
#  <!-- i : 이탤리체 -->
#  <i>
#                  All I need is Love.
#              </i>
#  </p>]

# %%
# 특정 태그 확인
soup.find_all(class_ = "outer-text")
# Out:
# [<p class="outer-text first-item" id="second">
#  <!-- b : 볼드체 -->
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>,
#  <p class="outer-text">
#  <!-- i : 이탤리체 -->
#  <i>
#                  All I need is Love.
#              </i>
#  </p>]

# %%
soup.find_all(id = "pw-link")
# Out:
# [<a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>]

# %%
# 리스트 안에 있기 때문에 인덱스를 활용하여 텍스트를 추출할 수 있음
# .text
# .string
# .get_text()
soup.find_all(id = "pw-link")[0].text
# Out:
# 'PinkWink'

# %%
soup.find_all("p", class_=  "inner-text second-item")
# Out:
# [<p class="inner-text second-item">
#                  Happy Data Science.
#                  <!-- target = "_blink" 속성을 추가하면 새 탭에서 해당 링크가 열림-->
#  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>]

# %%
# p 태그 리스트에서 텍스트 속성만 출력
for each_tag in soup.find_all("p"):
    print('=' * 50)
    print(each_tag.text)
# Out:
# ...
#
#                 Happy PinkWink.
#
# PinkWink
#
# ...
#
#                 Happy Data Science.
#
# Python
#
# ...
#
#
#
#                 Data Science is funny.
#
#
# ...
#
#
#
#                 All I need is Love.

# %%
# a 태그에서 href 속성값에 있는 값 추출
links = soup.find_all("a")
links
# Out:
# [<a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>,
#  <a href="https://www.python.org" id="py-link">Python</a>]

# %%
# href 속성을 가져오는 2가지 방법
print(links[0].get("href"))
print(links[1]["href"])
# Out:
# http://www.pinkwink.kr
# https://www.python.org

# %%
for each in links:
    href = each.get("href") #each["href"]
    text = each.get_text()
    print(text + " => " + href)
# Out:
# PinkWink => http://www.pinkwink.kr
# Python => https://www.python.org

# %% [markdown]
# ## BeautifulSoup 예제 1-1. 네이버 금융

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
url = "https://finance.naver.com/marketindex/"
page = urlopen(url) # 보통 response, res 변수를 많이 사용
# page.status 웹 페이지가 어떤 상태인지 표시해줌
# https://namu.wiki/w/HTTP/%EC%9D%91%EB%8B%B5%20%EC%BD%94%EB%93%9C
soup = BeautifulSoup(page, "html.parser")
print(soup)
# Out:
# <script language="javascript" src="/template/head_js.naver?referer=info.finance.naver.com&amp;menu=marketindex&amp;submenu=market"></script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20230803180530/js/info/jindo.min.ns.1.5.3.euckr.js" type="text/javascript"></script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20230803180530/js/jindo.1.5.3.element-text-patch.js" type="text/javascript"></script>
# <div id="container" style="padding-bottom:0px;">
# <div class="market_include">
# <div class="market_data">
# <div class="market1">
# <div class="title">
# <h2 class="h_market1"><span>환전 고시 환율</span></h2>
# </div>
# <!-- data -->
# <div class="data">
# <ul class="data_lst" id="exchangeList">
# <li class="on">
# <a class="head usd" href="/marketindex/exchangeDetail.naver?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'fr1.usdt', '', '', event);">
# <h3 class="h_lst"><span class="blind">미국 USD</span></h3>
# <div class="head_info point_dn">
# ...

# %%
# 1번째 방법
soup.find_all("span", "value")
# Out:
# [<span class="value">1,307.00</span>,
#  <span class="value">918.45</span>,
#  <span class="value">1,434.69</span>,
#  <span class="value">181.44</span>,
#  <span class="value">141.7500</span>,
#  <span class="value">1.1026</span>,
#  <span class="value">1.2748</span>,
#  <span class="value">101.8300</span>,
#  <span class="value">82.82</span>,
#  <span class="value">1687.85</span>,
#  <span class="value">1976.1</span>,
#  <span class="value">81293.83</span>]

# %%
soup.find_all(class="value")
# Out:
#   Cell In[7], line 1
#     soup.find_all(class="value")
#                   ^
# SyntaxError: invalid syntax

# %%
# 2번째 방법
soup.find_all("span", class_ = "value")
# Out:
# [<span class="value">1,308.00</span>,
#  <span class="value">918.83</span>,
#  <span class="value">1,435.27</span>,
#  <span class="value">181.67</span>,
#  <span class="value">141.7500</span>,
#  <span class="value">1.1026</span>,
#  <span class="value">1.2748</span>,
#  <span class="value">101.8300</span>,
#  <span class="value">82.82</span>,
#  <span class="value">1687.85</span>,
#  <span class="value">1976.1</span>,
#  <span class="value">81343.6</span>]

# %%
# 3번째 방법
soup.find_all("span", {"class" : "value"})
# Out:
# [<span class="value">1,307.00</span>,
#  <span class="value">918.45</span>,
#  <span class="value">1,434.69</span>,
#  <span class="value">181.44</span>,
#  <span class="value">141.7500</span>,
#  <span class="value">1.1026</span>,
#  <span class="value">1.2748</span>,
#  <span class="value">101.8300</span>,
#  <span class="value">82.82</span>,
#  <span class="value">1687.85</span>,
#  <span class="value">1976.1</span>,
#  <span class="value">81293.83</span>]

# %%
# 미국 환율 정보 가져오기
# .text
# .string
# .get_text()
soup.find_all("span", {"class" : "value"})[0].text
# Out:
# '1,307.00'

# %% [markdown]
# ## BeautifulSoup 예제 1-2. 네이버 금융
# - ! pip install requests
# - find, find_all
# - select, select_one
# - find, select_one : 단일 선택
# - select, find_all : 다중 선택

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests #from urlib.request.Request와 같은 기능
from bs4 import BeautifulSoup

# %%
url = "https://finance.naver.com/marketindex/"
response = requests.get(url) #get방식, post 방식
soup = BeautifulSoup(response.text, "html.parser")
print(soup.prettify())
# Out:
# <script language="javascript" src="/template/head_js.naver?referer=info.finance.naver.com&amp;menu=marketindex&amp;submenu=market">
# </script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20230803180530/js/info/jindo.min.ns.1.5.3.euckr.js" type="text/javascript">
# </script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20230803180530/js/jindo.1.5.3.element-text-patch.js" type="text/javascript">
# </script>
# <div id="container" style="padding-bottom:0px;">
#  <div class="market_include">
#   <div class="market_data">
#    <div class="market1">
#     <div class="title">
#      <h2 class="h_market1">
#       <span>
#        환전 고시 환율
#       </span>
#      </h2>
#     </div>
#     <!-- data -->
#     <div class="data">
#      <ul class="data_lst" id="exchangeList">
#       <li class="on">
#        <a class="head usd" href="/marketindex/exchangeDetail.naver?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'fr1.usdt', '', '', event);">
# ...

# %%
# soup.find_all ("li", "on")
# id => #
# class => .
# id는 고유한 값이기 때문에 다른 것들에 비해 많이 사용됨

exchangeList = soup.select("#exchangeList > li") #id가 exchangeList 인 li 태그
exchangeList
# Out:
# [<li class="on">
#  <a class="head usd" href="/marketindex/exchangeDetail.naver?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'fr1.usdt', '', '', event);">
#  <h3 class="h_lst"><span class="blind">미국 USD</span></h3>
#  <div class="head_info point_dn">
#  <span class="value">1,306.50</span>
#  <span class="txt_krw"><span class="blind">원</span></span>
#  <span class="change"> 1.50</span>
#  <span class="blind">하락</span>
#  </div>
#  </a>
#  <a class="graph_img" href="/marketindex/exchangeDetail.naver?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'fr1.usdc', '', '', event);">
#  <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/FX_USDKRW.png" width="295"/>
#  </a>
#  <div class="graph_info">
#  <span class="time">2023.08.07 18:01</span>
#  <span class="source">하나은행 기준</span>
#  <span class="count">고시회차<span class="num">719</span>회</span>
#  </div>
#  </li>,
#  <li class="">
# ...

# %%
exchangeList[0].select_one(".h_lst").text
# Out:
# '미국 USD'

# %%
title = exchangeList[0].select_one(".h_lst").text
exchange = exchangeList[0].select_one(".value").text
change = exchangeList[0].select_one(".change").text
# head_info point_dn 와 같이 표시된 것은 속성값이 head_info와 point_dn으로 나뉘어져있는 것으로
# 속성값이 2개임을 표시해주어야 한다. 
# 그래서 div 태그 밑의 .head_info.point_dn 클래스를 가져와라 라고 표시한 것이다.
# div.head_info.point_dn.blind 을 하게되면 처음으로 만나는 blind가 있어서 다른 값이 나오는데
# div.head_info.point_dn 바로 하위 속성의 blind를 추출하라는 뜻으로 > 을 작성해준다.
# div 태그임을 생략해줘도 됨
# select는 하위 속성값들을 한번에 표시할 수 있다는 장점이 있음
updown = exchangeList[0].select_one("div.head_info.point_dn > .blind").text


title, exchange, change, updown
# Out:
# ('미국 USD', '1,306.50', ' 1.50', '하락')

# %%
exchangeList[0].select_one("a").get("href")
# Out:
# '/marketindex/exchangeDetail.naver?marketindexCd=FX_USDKRW'

# %%
# exchangeList[0].select_one("a").get("href") 만 하면
# 앞에 링크 주소가 짤려 나오기 때문에 페이지를 열 수 없다.
# 링크를 연결해주는 기능도 있지만,
# 아래와 같이 연결해줄 수도 있다.

baseUrl = "https://finance.naver.com"
link = baseUrl + exchangeList[0].select_one("a").get("href")
# Out:
# 'https://finance.naver.com/marketindex/exchangeDetail.naver?marketindexCd=FX_USDKRW'

# %%
# 4개 데이터 수집

exchange_datas = []
baseUrl = "https://finance.naver.com"

for item in exchangeList:
    data = {
        "title" : item.select_one(".h_lst").text,
        "exchange" : item.select_one(".value").text,
        "change" : item.select_one(".change").text,
        "updown" : item.select_one("div.head_info.point_dn > .blind").text,
        "link" : baseUrl + item.select_one("a").get("href")
    }
    exchange_datas.append(data)
exchange_datas
# Out:
# [{'title': '미국 USD',
#   'exchange': '1,306.50',
#   'change': ' 1.50',
#   'updown': '하락',
#   'link': 'https://finance.naver.com/marketindex/exchangeDetail.naver?marketindexCd=FX_USDKRW'},
#  {'title': '일본 JPY(100엔)',
#   'exchange': '917.84',
#   'change': ' 4.85',
#   'updown': '하락',
#   'link': 'https://finance.naver.com/marketindex/exchangeDetail.naver?marketindexCd=FX_JPYKRW'},
#  {'title': '유럽연합 EUR',
#   'exchange': '1,434.15',
#   'change': ' 5.83',
#   'updown': '하락',
#   'link': 'https://finance.naver.com/marketindex/exchangeDetail.naver?marketindexCd=FX_EURKRW'},
#  {'title': '중국 CNY',
#   'exchange': '181.55',
#   'change': ' 0.42',
#   'updown': '하락',
#   'link': 'https://finance.naver.com/marketindex/exchangeDetail.naver?marketindexCd=FX_CNYKRW'}]

# %%
import pandas as pd

df = pd.DataFrame(exchange_datas)
df
# Out:
#           title  exchange change updown  \
# 0        미국 USD  1,306.50   1.50     하락
# 1  일본 JPY(100엔)    917.84   4.85     하락
# 2      유럽연합 EUR  1,434.15   5.83     하락
# 3        중국 CNY    181.55   0.42     하락
#
#                                                 link
# 0  https://finance.naver.com/marketindex/exchange...
# 1  https://finance.naver.com/marketindex/exchange...
# 2  https://finance.naver.com/marketindex/exchange...
# 3  https://finance.naver.com/marketindex/exchange...

# %%
df.to_excel("./naverfinance.xlsx", encoding = "utf-8")
# Out:
# c:\Users\nabi4\anaconda3\envs\ds_study\lib\site-packages\pandas\util\_decorators.py:211: FutureWarning: the 'encoding' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'encoding'
#   return func(*args, **kwargs)

# %% [markdown]
# - 위 코드를 하나의 .py 파일로 만들어서 터미널에 python 파일명.py를 실행해주면
# - 한 번에 크롤링한 데이터를 엑셀 파일로 만들어주는 기능을 하는 파일을 만든 것이다.

# %% [markdown]
# ## BeautifulSoup 예제 2 - 위키백과 문서 정보 가져오기

# %%
# 한글로 되어있는 URL을 복사 붙여넣기하면
# https://ko.wikipedia.org/wiki/%EC%95%85%EA%B7%80_(%EB%93%9C%EB%9D%BC%EB%A7%88)
# 위와 같이 깨지는 것을 볼 수 있다.

# 이런 경우에는 
# URL을 decode해주는 https://www.urldecoder.org/
# 위와 같은 홈페이지에 들어가
# https://ko.wikipedia.org/wiki/악귀_(드라마)
# decode된 url 주소를 얻거나

# 아래와 같이 포매팅을 해주어야함.
import urllib
from urllib.request import urlopen, Request
html = "https://ko.wikipedia.org/wiki/{search_words}"
req = Request(html.format(search_words = urllib.parse.quote("악귀_(드라마)"))) #글자를 url로 인코딩
response = urlopen(req)
soup = BeautifulSoup(response, "html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled" dir="ltr" lang="ko">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    악귀 (드라마) - 위키백과, 우리 모두의 백과사전
#   </title>
#   <script>
# ...

# %%
# 등장인물, 주요인물 정보 찾기

n = 0

for each in soup.find_all("ul"):
    print("->" + str(n) + "================")
    print(each.get_text())
    n += 1
# Out:
# ->0================
#
# 대문최근 바뀜요즘 화제임의의 문서로기부
#
# ->1================
#
# 사랑방사용자 모임관리 요청
#
# ->2================
#
# 도움말정책과 지침질문방
#
# ->3================
#
# 계정 만들기로그인
#
# ->4================
#
#  계정 만들기 로그인
#
# ->5================
#
# 기여토론
#
# ->6================
#
#
#
# 처음 위치
#
#
#
#
#
# 1프로그램 소개
#
#
#
#
#
#
#
# 2제작진
#
#
#
# 제작진 하위섹션 토글하기
#
#
#
#
#
# 2.1제작
#
#
#
#
#
#
#
# 2.2제작사
#
#
#
#
#
#
#
# 2.3극본
#
#
#
#
#
#
#
# 2.4연출
#
#
#
#
#
#
#
#
#
# 3출연진
#
#
#
# 출연진 하위섹션 토글하기
#
#
#
#
#
# 3.1주요 인물
#
#
#
#
#
#
#
# 3.2산영 주변 인물
#
#
#
#
#
#
#
# 3.3화원재
#
#
#
#
#
#
#
# 3.4중현 캐피탈
#
#
#
#
#
#
#
# 3.5강력범죄수사대
#
#
#
#
#
#
#
# 3.6귀신
#
#
#
#
#
#
#
# 3.7그 외 인물
#
#
#
#
#
#
#
# 3.8특별 출연
#
#
#
#
#
#
#
#
#
# 4시청률
#
#
#
#
#
#
#
# 5참고 사항
#
#
#
#
#
#
#
# 6각주
#
#
#
#
#
#
#
# 7외부 링크
#
#
#
#
#
# ->7================
#
#
# ->8================
#
#
#
#
# 2.1제작
#
#
#
#
#
#
#
# 2.2제작사
#
#
#
#
#
#
#
# 2.3극본
#
#
#
#
#
#
#
# 2.4연출
#
#
#
#
#
# ->9================
#
#
# ->10================
#
#
# ->11================
#
#
# ...

# %%
# 개발자도구에서 주인공 이름이 나오는 곳 찾기

soup.find_all("li")[72]
# Out:
# <li><a href="/wiki/%EA%B9%80%ED%83%9C%EB%A6%AC" title="김태리">김태리</a> : 구산영 역 (아역 : <a href="/wiki/%EC%B5%9C%EC%86%8C%EC%9C%A8" title="최소율">최소율</a>) - <b>무인년 戊寅年, 범띠, 25세, 여.</b></li>

# %%
soup.find_all("li")[73]
# Out:
# <li><a href="/wiki/%EC%98%A4%EC%A0%95%EC%84%B8" title="오정세">오정세</a> : 염해상 역 (아역 : 진재희, <a href="/wiki/%ED%95%A8%EC%84%B1%EB%AF%BC" title="함성민">함성민</a>) - <b>계해년 癸亥年, 돼지띠, 40세, 남.</b></li>

# %%
soup.find_all("li")[74]
# Out:
# <li><a href="/wiki/%ED%99%8D%EA%B2%BD" title="홍경">홍경</a> : 이홍새 역 - <b>병자년 丙子年, 쥐띠, 27세, 남.</b></li>

# %%
soup.find_all("li")[72].text.strip()
# Out:
# '김태리\xa0: 구산영 역 (아역\xa0: 최소율) - 무인년 戊寅年, 범띠, 25세, 여.'

# %%
soup.find_all("li")[72].text.strip().replace("\xa0", " ")
# Out:
# '김태리 : 구산영 역 (아역 : 최소율) - 무인년 戊寅年, 범띠, 25세, 여.'

# %%
# 이름 추출
# 공백을 구분자로 문자열을 나눈후
# 첫번째 문자열을 가져옴
soup.find_all("li")[72].text.strip().replace("\xa0", " ").split()[0]
# Out:
# '김태리'

# %%
for idx in range(72, 75):
    print(soup.find_all("li")[idx].text.strip().replace("\xa0", " ").split()[0])
# Out:
# 김태리
# 오정세
# 홍경

# %% [markdown]
# ## Python List 데이터형

# %% [markdown]
# - list형은 대괄호로 생성

# %%
colors = ['red', 'blue', 'green']

colors
# Out:
# ['red', 'blue', 'green']

# %%
b = colors
b
# Out:
# ['red', 'blue', 'green']

# %%
b[1] = "black"
b
# Out:
# ['red', 'black', 'green']

# %%
colors
# Out:
# ['red', 'black', 'green']

# %%
c = colors.copy()
c
# Out:
# ['red', 'black', 'green']

# %%
c[1] = "yellow"
c
# Out:
# ['red', 'yellow', 'green']

# %%
colors
# Out:
# ['red', 'black', 'green']

# %% [markdown]
# - list형을 반복문 for 적용

# %%
for color in colors:
    print(color)
# Out:
# red
# black
# green

# %% [markdown]
# - in 명령 조건문 적용

# %%
if "black" in colors:
    print("True")
# Out:
# True

# %%
movies = ['라라랜드', '먼 훗날 우리', '어벤져스', '다크나이트']
movies
# Out:
# ['라라랜드', '먼 훗날 우리', '어벤져스', '다크나이트']

# %% [markdown]
# - append : list 제일 뒤에 추가

# %%
movies.append("타이타닉")
movies
# Out:
# ['라라랜드', '먼 훗날 우리', '어벤져스', '다크나이트', '타이타닉']

# %% [markdown]
# - pop : list 제일 뒤 자료를 하나씩 삭제

# %%
movies.pop()
movies
# Out:
# ['라라랜드', '먼 훗날 우리', '어벤져스', '다크나이트']

# %% [markdown]
# - extend : 제일 뒤에 자료 추가

# %%
movies.extend(['위대한쇼맨', '인셉션', '터미네이터'])
movies
# Out:
# ['라라랜드', '먼 훗날 우리', '어벤져스', '다크나이트', '위대한쇼맨', '인셉션', '터미네이터']

# %% [markdown]
# - remove : 자료 삭제

# %%
movies.remove("어벤져스")
movies
# Out:
# ['라라랜드', '먼 훗날 우리', '다크나이트', '위대한쇼맨', '인셉션', '터미네이터']

# %% [markdown]
# - 슬라이싱 : [n:m] n부터 m-1까지

# %%
movies[3:5]
# Out:
# ['위대한쇼맨', '인셉션']

# %%
favorite_movies = movies[3:5]
favorite_movies
# Out:
# ['위대한쇼맨', '인셉션']

# %% [markdown]
# - inset : 원하는 위치에 아이템 삽입

# %%
favorite_movies.insert(1, 9.60)
favorite_movies
# Out:
# ['위대한쇼맨', 9.6, '인셉션']

# %%
favorite_movies.insert(3, 9.50)
favorite_movies
# Out:
# ['위대한쇼맨', 9.6, '인셉션', 9.5]

# %% [markdown]
# - list안에 list

# %%
favorite_movies.insert(5, ["휴잭맨", "레오나르도 디카프리오"])
favorite_movies
# Out:
# ['위대한쇼맨', 9.6, '인셉션', 9.5, ['휴잭맨', '레오나르도 디카프리오']]

# %% [markdown]
# - isinstance : 자료형 확인

# %%
isinstance(favorite_movies, list)
# Out:
# True

# %%
for each_item in favorite_movies:
    if isinstance(each_item, list):
        for nested_item in each_item:
            print("nested_item", nested_item)
    else:
        print("each_item", each_item)
# Out:
# each_item 위대한쇼맨
# each_item 9.6
# each_item 인셉션
# each_item 9.5
# nested_item 휴잭맨
# nested_item 레오나르도 디카프리오

# %% [markdown]
# ***

# %% [markdown]
# ## 2. 시카고 맛집 데이터 분석 - 개요
# - the 50 best sandwiches in chicago
# - https://www.chicagomag.com/chicago-magazine/november-2012/best-sandwiches-chicago/
# - 최종 목표 : 총 51개 페이지에서 각 가게의 정보를 가져와보자
#     - 가게 이름
#     - 대표 메뉴
#     - 대표 메뉴의 가격
#     - 가게 주소

# %% [markdown]
# ## 3. 시카고 맛집 데이터 분석 - 메인 페이지

# %%
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup

# 가게 웹 페이지 데이터가 상대경로로 되어있기 때문에
# 나중에 url_base와 합쳐주기 위함
url_base = "https://www.chicagomag.com/"
url_sub = "chicago-magazine/november-2012/best-sandwiches-chicago/"
url = url_base + url_sub

# response = urlopen(url) #403 에러. 서버에서 우리의 접근을 막음
# 간혹 어떤 사이트들에서는 위와 같은 에러가 뜨는데,
# 방법 1
# 개발자도구 - Network - Headers - Request-Headers - User-Agent
# 에 들아가 아래와 같이 딕셔너리 형태로 써주거나
# {"User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36"}

# 간단하게 아래와 같이 표시해줘도 된다.
# 방법 2
req = Request(url, headers = {"User-Agent" : "Chrome"})
response = urlopen(req)

response.status
# Out:
# 200

# %%
pip install fake-useragent
# Out:
# ...
#   Obtaining dependency information for fake-useragent from https://files.pythonhosted.org/packages/d0/4b/1479877468e20c9a5719336a52bb0ee6f822d387b67f05a0c81e098064cc/fake_useragent-1.2.1-py3-none-any.whl.metadata
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# 방법 3
# fake_useragent 모듈 사용
from fake_useragent import UserAgent

ua = UserAgent()
ua.ie
req = Request(url, headers = {"User-Agent" : ua.ie})
response = urlopen(req)

response.status
# Out:
# Error occurred during getting browser: ie, but was suppressed with fallback.
# Error occurred during getting browser: ie, but was suppressed with fallback.
# 200

# %%
soup = BeautifulSoup(response, "html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible">
#    <link href="https://gmpg.org/xfn/11" rel="profile"/>
#    <script src="https://cmp.osano.com/16A1AnRt2Fn8i1unj/f15ebf08-7008-40fe-9af3-db96dc3e8266/osano.js">
#    </script>
#    <title>
#     The 50 Best Sandwiches in Chicago – Chicago Magazine
#    </title>
#    <style type="text/css">
#     .heateor_sss_button_instagram span.heateor_sss_svg,a.heateor_sss_instagram span.heateor_sss_svg{background:radial-gradient(circle at 30% 107%,#fdf497 0,#fdf497 5%,#fd5949 45%,#d6249f 60%,#285aeb 90%)}
# 						div.heateor_sss_horizontal_sharing a.heateor_sss_button_instagram span{background:#000!important;}div.heateor_sss_standard_follow_icons_container a.heateor_sss_button_instagram span{background:#000;}
# 										.heateor_sss_horizontal_sharing .heateor_sss_svg,.heateor_sss_standard_follow_icons_container .heateor_sss_svg{
# ...

# %%
soup.find_all("div", class_ = "sammy"), len(soup.find_all("div", class_ = "sammy"))
# soup.select(".sammy"), len(soup.select(".sammy"))
# Out:
# ([<div class="sammy" style="position: relative;">
#   <div class="sammyRank">1</div>
#   <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/"><b>BLT</b><br/>
#   Old Oak Tap<br/>
#   <em>Read more</em> </a></div>
#   </div>,
#   <div class="sammy" style="position: relative;">
#   <div class="sammyRank">2</div>
#   <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Au-Cheval-Fried-Bologna/"><b>Fried Bologna</b><br/>
#   Au Cheval<br/>
#   <em>Read more</em> </a></div>
#   </div>,
#   <div class="sammy" style="position: relative;">
#   <div class="sammyRank">3</div>
#   <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Xoco-Woodland-Mushroom/"><b>Woodland Mushroom</b><br/>
#   Xoco<br/>
#   <em>Read more</em> </a></div>
#   </div>,
#   <div class="sammy" style="position: relative;">
#   <div class="sammyRank">4</div>
# ...

# %%
tmp_one = soup.find_all("div", class_ = "sammy")[0]
tmp_one
# Out:
# <div class="sammy" style="position: relative;">
# <div class="sammyRank">1</div>
# <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/"><b>BLT</b><br/>
# Old Oak Tap<br/>
# <em>Read more</em> </a></div>
# </div>

# %%
# 가게 랭크
tmp_one.find(class_ = "sammyRank").get_text()
# tmp_one.select_one(".sammyRank").text
# Out:
# '1'

# %%
# 음식 이름, 가게 이름
tmp_one.find("div", {"class" : "sammyListing"}).text
# tmp_one.select_one(".sammyListing").text
# Out:
# 'BLT\nOld Oak Tap\nRead more '

# %%
# 가게 사이트
tmp_one.find("a")["href"]
# tmp_one.select_one("a")["href"] #.get("href")라 써도 됨
# Out:
# '/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/'

# %%
import re

tmp_string = tmp_one.find(class_="sammyListing").get_text()
re.split(("\n|\r\n"), tmp_string) # 필요없는 문자열 삭제
# Out:
# ['BLT', 'Old Oak Tap', 'Read more ']

# %%
# 음식 이름, 가게 이름
print(re.split(("\n|\r\n"), tmp_string)[0])
print(re.split(("\n|\r\n"), tmp_string)[1])
# Out:
# BLT
# Old Oak Tap

# %%
## 테스트 해본 코드를 반복문을 이용해 여러 데이터 추출


from urllib.parse import urljoin

url_base
# Out:
# 'https://www.chicagomag.com/'

# %%
# 필요한 내용을 담을 빈 리스트
# 리스트로 하나씩 컬럼을 만들고 DataFrame으로 합칠 예정
rank = []
main_menu = []
cafe_name = []
url_add = []

# %%
list_soup = soup.find_all("div", class_ = "sammy") #soup.select(".sammy")

for item in list_soup:
    rank.append(item.find(class_ = "sammyRank").get_text())
    tmp_string = item.find(class_ = "sammyListing").get_text()
    main_menu.append(re.split(("\n|\r\n"), tmp_string)[0])
    cafe_name.append(re.split(("\n|\r\n"), tmp_string)[1])
    url_add.append(urljoin(url_base, item.find("a")["href"]))

# %%
len(rank), len(main_menu), len(cafe_name), len(url_add)
# Out:
# (50, 50, 50, 50)

# %%
import pandas as pd

data = {
    "Rank" : rank,
    "Menu" : main_menu,
    "Cafe" : cafe_name,
    "URL" : url_add
}

df = pd.DataFrame(data)
df.head()
# Out:
#   Rank               Menu                    Cafe  \
# 0    1                BLT             Old Oak Tap
# 1    2      Fried Bologna               Au Cheval
# 2    3  Woodland Mushroom                    Xoco
# 3    4         Roast Beef               Al’s Deli
# 4    5               PB&L  Publican Quality Meats
#
#                                                  URL
# 0  https://www.chicagomag.com/Chicago-Magazine/No...
# 1  https://www.chicagomag.com/Chicago-Magazine/No...
# 2  https://www.chicagomag.com/Chicago-Magazine/No...
# 3  https://www.chicagomag.com/Chicago-Magazine/No...
# 4  https://www.chicagomag.com/Chicago-Magazine/No...

# %%
# 컬럼 순서 변경
df = pd.DataFrame(data, columns = ["Rank", "Cafe", "Menu", "URL"])
df.tail()
# Out:
#    Rank                    Cafe                Menu  \
# 45   46                Chickpea               Kufta
# 46   47  The Goddess and Grocer  Debbie’s Egg Salad
# 47   48                 Zenwich          Beef Curry
# 48   49         Toni Patisserie       Le Végétarien
# 49   50         Phoebe’s Bakery          The Gatsby
#
#                                                   URL
# 45  https://www.chicagomag.com/Chicago-Magazine/No...
# 46  https://www.chicagomag.com/Chicago-Magazine/No...
# 47  https://www.chicagomag.com/Chicago-Magazine/No...
# 48  https://www.chicagomag.com/Chicago-Magazine/No...
# 49  https://www.chicagomag.com/Chicago-Magazine/No...

# %%
# 데이터 저장

df.to_csv("../data/03. best_sandwiches_list_chicago.csv", sep=",", encoding = "utf-8")

# %% [markdown]
# ## 4. 시카고 맛집 데이터 분석 - 하위페이지

# %%
# requirements

import pandas as pd
from urllib.request import urlopen
from bs4 import BeautifulSoup
from fake_useragent import UserAgent

# %%
df = pd.read_csv("../data/03. best_sandwiches_list_chicago.csv", index_col = 0)
df.head()
# Out:
#    Rank                    Cafe               Menu  \
# 0     1             Old Oak Tap                BLT
# 1     2               Au Cheval      Fried Bologna
# 2     3                    Xoco  Woodland Mushroom
# 3     4               Al’s Deli         Roast Beef
# 4     5  Publican Quality Meats               PB&L
#
#                                                  URL
# 0  https://www.chicagomag.com/Chicago-Magazine/No...
# 1  https://www.chicagomag.com/Chicago-Magazine/No...
# 2  https://www.chicagomag.com/Chicago-Magazine/No...
# 3  https://www.chicagomag.com/Chicago-Magazine/No...
# 4  https://www.chicagomag.com/Chicago-Magazine/No...

# %%
df["URL"][0]
# Out:
# 'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/'

# %%
ua = UserAgent()
req = Request(df["URL"][0], headers = {"user-agent" : ua.ie})
html = urlopen(req).read()
soup_tmp = BeautifulSoup(html, "html.parser")
soup_tmp.find("p", class_ = "addy") #soup.find.select_one(".addy")
# Out:
# Error occurred during getting browser: ie, but was suppressed with fallback.
# <p class="addy">
# <em>$10. 2109 W. Chicago Ave., 773-772-0406, <a href="http://www.theoldoaktap.com/">theoldoaktap.com</a></em></p>

# %%
# Regular expression

price_tmp = soup_tmp.find("p", class_ = "addy") .text
price_tmp
# Out:
# '\n$10. 2109 W. Chicago Ave., 773-772-0406, theoldoaktap.com'

# %%
import re
re.split(".,", price_tmp)
# Out:
# ['\n$10. 2109 W. Chicago Ave', ' 773-772-040', ' theoldoaktap.com']

# %%
price_tmp = re.split(".,", price_tmp)[0]
price_tmp
# Out:
# '\n$10. 2109 W. Chicago Ave'

# %%
re.search("\$\d+\.(\d+)?", price_tmp).group() #.group()을 해줘야 값이 추출됨
# Out:
# '$10.'

# %%
tmp = re.search("\$\d+\.(\d+)?", price_tmp).group()
price_tmp[len(tmp) + 2:] # 가격 데이터 뒤에 띄어쓰기가 하나 있으므로 2칸째부터 추출해야함
# Out:
# '2109 W. Chicago Ave'

# %%
df.head()
# Out:
#    Rank                    Cafe               Menu  \
# 0     1             Old Oak Tap                BLT
# 1     2               Au Cheval      Fried Bologna
# 2     3                    Xoco  Woodland Mushroom
# 3     4               Al’s Deli         Roast Beef
# 4     5  Publican Quality Meats               PB&L
#
#                                                  URL
# 0  https://www.chicagomag.com/Chicago-Magazine/No...
# 1  https://www.chicagomag.com/Chicago-Magazine/No...
# 2  https://www.chicagomag.com/Chicago-Magazine/No...
# 3  https://www.chicagomag.com/Chicago-Magazine/No...
# 4  https://www.chicagomag.com/Chicago-Magazine/No...

# %%
# 전체 데이터 추출 전, 테스트

price = []
address = []
ua = UserAgent()

for n in df.index[:3]:    
    req = Request(df["URL"][n], headers = {"user-agent" : ua.ie})
    html = urlopen(req).read()
    soup_tmp = BeautifulSoup(html, "html.parser")
    gettings = soup_tmp.find("p", class_ = "addy").get_text()
    price_tmp = re.split(".,", gettings)[0]
    tmp = re.search("\$\d+\.(\d+)?", price_tmp).group()
    price.append(tmp)
    address.append(price_tmp[len(tmp) + 2:])
    print(n)
print(price)
print(address)
# Out:
# Error occurred during getting browser: ie, but was suppressed with fallback.
# Error occurred during getting browser: ie, but was suppressed with fallback.
# 0
# Error occurred during getting browser: ie, but was suppressed with fallback.
# 1
# 2
# ['$10.', '$9.', '$9.50']
# ['2109 W. Chicago Ave', '800 W. Randolph St', ' 445 N. Clark St']

# %%
# itterows() 를 사용하는 방법

price = []
address = []
ua = UserAgent()

for idx, row in df[:3].iterrows():    
    req = Request(row["URL"], headers = {"user-agent" : ua.ie})
    html = urlopen(req).read()
    soup_tmp = BeautifulSoup(html, "html.parser")
    gettings = soup_tmp.find("p", class_ = "addy").get_text()
    price_tmp = re.split(".,", gettings)[0]
    tmp = re.search("\$\d+\.(\d+)?", price_tmp).group()
    price.append(tmp)
    address.append(price_tmp[len(tmp) + 2:])
    print(idx)
print(price)
print(address)
# Out:
# Error occurred during getting browser: ie, but was suppressed with fallback.
# Error occurred during getting browser: ie, but was suppressed with fallback.
# 0
# Error occurred during getting browser: ie, but was suppressed with fallback.
# 1
# 2
# ['$10.', '$9.', '$9.50']
# ['2109 W. Chicago Ave', '800 W. Randolph St', ' 445 N. Clark St']

# %%
# 코드가 정상적으로 진행되는 것을 보기 위해 인덱스를 추출하는거 말고 이쁘게 나타내는 다른 방법은 없을까?
! pip install tqdm
# Out:
# ...
#      ---------------------------------------- 0.0/77.1 kB ? eta -:--:--
#      ---------------------------------------- 77.1/77.1 kB 4.5 MB/s eta 0:00:00
# ...

# %%
from tqdm import tqdm

price = []
address = []
ua = UserAgent()

for idx, row in tqdm(df.iterrows()):    
    req = Request(row["URL"], headers = {"user-agent" : ua.ie})
    html = urlopen(req).read()
    soup_tmp = BeautifulSoup(html, "html.parser")
    gettings = soup_tmp.find("p", class_ = "addy").get_text()
    price_tmp = re.split(".,", gettings)[0]
    tmp = re.search("\$\d+\.(\d+)?", price_tmp).group()
    price.append(tmp)
    address.append(price_tmp[len(tmp) + 2:])
# Out:
# 0it [00:00, ?it/s]Error occurred during getting browser: ie, but was suppressed with fallback.
# 1it [00:01,  1.67s/it]Error occurred during getting browser: ie, but was suppressed with fallback.
# 2it [00:02,  1.43s/it]Error occurred during getting browser: ie, but was suppressed with fallback.
# 3it [00:04,  1.34s/it]Error occurred during getting browser: ie, but was suppressed with fallback.
# 4it [00:05,  1.29s/it]Error occurred during getting browser: ie, but was suppressed with fallback.
# 5it [00:07,  1.58s/it]Error occurred during getting browser: ie, but was suppressed with fallback.
# 6it [00:09,  1.84s/it]Error occurred during getting browser: ie, but was suppressed with fallback.
# 7it [00:12,  1.96s/it]Error occurred during getting browser: ie, but was suppressed with fallback.
# 8it [00:13,  1.89s/it]Error occurred during getting browser: ie, but was suppressed with fallback.
# ...

# %%
len(price), len(address)
# Out:
# (50, 50)

# %%
df_result = df.loc[:, ["Rank", "Cafe", "Menu"]]
df_result["Price"] = price
df_result["Address"] = address

df_result.head()
# Out:
#    Rank                    Cafe               Menu  Price              Address
# 0     1             Old Oak Tap                BLT   $10.  2109 W. Chicago Ave
# 1     2               Au Cheval      Fried Bologna    $9.   800 W. Randolph St
# 2     3                    Xoco  Woodland Mushroom  $9.50      445 N. Clark St
# 3     4               Al’s Deli         Roast Beef  $9.40         914 Noyes St
# 4     5  Publican Quality Meats               PB&L   $10.    825 W. Fulton Mkt

# %%
df_result.to_csv('../data/03. best_sandwiches_list_chicago2.csv', sep = ",", encoding = "utf-8")

# %%
# 위 내용이 강의에서 배운 내용인데,
# 소수점 단위인 가격들은 주소를 추출한 코드 때문에
# 앞에 빈칸이 하나 같이 추출되는 것을 볼 수 있었다.

req = Request(df["URL"][2], headers = {"user-agent" : ua.ie})
html = urlopen(req).read()
soup_tmp = BeautifulSoup(html, "html.parser")
gettings = soup_tmp.find("p", class_ = "addy").get_text()
price_tmp = re.split(".,", gettings)[0]
print(price_tmp)
tmp = re.search("\$\d+\.(\d+)?", price_tmp).group()
print(tmp)
print(price_tmp[len(tmp) + 2:])
# Out:
# Error occurred during getting browser: ie, but was suppressed with fallback.
# $9.50. 445 N. Clark St
# $9.50
#  445 N. Clark St

# %%
# re.split(".,", gettings)[0] 를 출력해보면, 가격 앞에 \n 이 들어가있다.
# 이를 제거해주고 첫 번째 공백 기준으로 가격과 주소를 나눠준다.

price_tmp = price_tmp.replace("\n", "")
print(price_tmp)
price_tmp.split(" ", 1) # 가격과 주소 사이에는 첫 번째 공백이 생긴다.
# Out:
# $9.50. 445 N. Clark St
# ['$9.50.', '445 N. Clark St']

# %%
req = Request(df["URL"][2], headers = {"user-agent" : ua.ie})
html = urlopen(req).read()
soup_tmp = BeautifulSoup(html, "html.parser")
gettings = soup_tmp.find("p", class_ = "addy").get_text()
price_tmp = re.split(".,", gettings)[0].replace("\n", "")
tmp = price_tmp.split(" ", 1)[0]
add = price_tmp.split(" ", 1)[1]
print(tmp)
print(add)

# 깔끔하게 출력된다.
# Out:
# Error occurred during getting browser: ie, but was suppressed with fallback.
# $9.50.
# 445 N. Clark St

# %%
# 공백 하나가 지금은 신경 안 써도 되는 문자일지도 모르겠지만
# 데이터는 통일해주는 것이 더 깔끔할 것 같아서
# 한 번 추가적으로 코드를 짜봤다 :) 
from tqdm import tqdm

price = []
address = []
ua = UserAgent()

for idx, row in tqdm(df.iterrows()):    
    req = Request(row["URL"], headers = {"user-agent" : ua.ie})
    html = urlopen(req).read()
    soup_tmp = BeautifulSoup(html, "html.parser")
    gettings = soup_tmp.find("p", class_ = "addy").get_text()
    price_tmp = re.split(".,", gettings)[0].replace("\n", "")
    tmp = price_tmp.split(" ", 1)[0]
    add = price_tmp.split(" ", 1)[1]
    price.append(tmp)
    address.append(add)

df_result = df.loc[:, ["Rank", "Cafe", "Menu"]]
df_result["Price"] = price
df_result["Address"] = address

df_result.head()
# 훨씬 깔끔해졌다 ㅎㅎ
# Out:
# 0it [00:00, ?it/s]Error occurred during getting browser: ie, but was suppressed with fallback.
# 1it [00:01,  1.28s/it]Error occurred during getting browser: ie, but was suppressed with fallback.
# 2it [00:02,  1.23s/it]Error occurred during getting browser: ie, but was suppressed with fallback.
# 3it [00:03,  1.24s/it]Error occurred during getting browser: ie, but was suppressed with fallback.
# 4it [00:04,  1.24s/it]Error occurred during getting browser: ie, but was suppressed with fallback.
# 5it [00:06,  1.24s/it]Error occurred during getting browser: ie, but was suppressed with fallback.
# 6it [00:07,  1.25s/it]Error occurred during getting browser: ie, but was suppressed with fallback.
# 7it [00:09,  1.47s/it]Error occurred during getting browser: ie, but was suppressed with fallback.
# 8it [00:11,  1.79s/it]Error occurred during getting browser: ie, but was suppressed with fallback.
# ...

# %%
# 그래도 강의 내용대로 따라가는게 좋으니, 강의 코드 대로 이후 학습을 진행했다.
df = pd.read_csv("../data/03. best_sandwiches_list_chicago2.csv", index_col = 0)
df.head()
# Out:
#    Rank                    Cafe               Menu  Price              Address
# 0     1             Old Oak Tap                BLT   $10.  2109 W. Chicago Ave
# 1     2               Au Cheval      Fried Bologna    $9.   800 W. Randolph St
# 2     3                    Xoco  Woodland Mushroom  $9.50      445 N. Clark St
# 3     4               Al’s Deli         Roast Beef  $9.40         914 Noyes St
# 4     5  Publican Quality Meats               PB&L   $10.    825 W. Fulton Mkt

# %% [markdown]
# ## 5. 시카고 맛집 데이터 지도 시각화

# %%
pip install folium
# Out:
# ...
#   Using cached folium-0.14.0-py2.py3-none-any.whl (102 kB)
# ...
#   Using cached branca-0.6.0-py3-none-any.whl (24 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install googlemaps
# Out:
# ...
#   Using cached googlemaps-4.10.0.tar.gz (33 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for googlemaps: filename=googlemaps-4.10.0-py3-none-any.whl size=40750 sha256=2abf4c68c30f2767d082f9192a66ef4d1bfec46641b9647c87fcaa47380223c1
#   Stored in directory: c:\users\nabi4\appdata\local\pip\cache\wheels\18\8a\74\69684f55a6b3e396f2b8e129f98b576cb02d6bebe66a0c3999
# Successfully built googlemaps
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium
import pandas as pd
import numpy as np
import googlemaps
from tqdm import tqdm

# %%
# 구글 계정 API Key  :  AIzaSyCGzzI7bY8eqleVZlZhEkPXDLALQJItCG4

# %%
df.head()
# Out:
#    Rank                    Cafe               Menu  Price              Address
# 0     1             Old Oak Tap                BLT   $10.  2109 W. Chicago Ave
# 1     2               Au Cheval      Fried Bologna    $9.   800 W. Randolph St
# 2     3                    Xoco  Woodland Mushroom  $9.50      445 N. Clark St
# 3     4               Al’s Deli         Roast Beef  $9.40         914 Noyes St
# 4     5  Publican Quality Meats               PB&L   $10.    825 W. Fulton Mkt

# %%
gmaps_key = "AIzaSyCGzzI7bY8eqleVZlZhEkPXDLALQJItCG4"
gmaps = googlemaps.Client(key = gmaps_key)

# %%
lat = []
lng = []

for idx, row in tqdm(df.iterrows()):
    if not row["Address"] == "Multiple location":
        target_name = row["Address"] + ", " + "Chicago"
        gmaps_output = gmaps.geocode(target_name)
        location_output = gmaps_output[0].get("geometry")
        lat.append(location_output["location"]["lat"])
        lng.append(location_output["location"]["lng"])
    else:
        lat.append(np.nan)
        lng.append(np.nan)
# Out:
# 50it [00:07,  6.97it/s]

# %%
len(lat), len(lng)
# Out:
# (50, 50)

# %%
df["lat"] = lat
df["lng"] = lng

df.head()
# Out:
#    Rank                    Cafe               Menu  Price  \
# 0     1             Old Oak Tap                BLT   $10.
# 1     2               Au Cheval      Fried Bologna    $9.
# 2     3                    Xoco  Woodland Mushroom  $9.50
# 3     4               Al’s Deli         Roast Beef  $9.40
# 4     5  Publican Quality Meats               PB&L   $10.
#
#                Address        lat        lng
# 0  2109 W. Chicago Ave  41.895558 -87.679967
# 1   800 W. Randolph St  41.884639 -87.647590
# 2      445 N. Clark St  41.890523 -87.630783
# 3         914 Noyes St  42.058322 -87.683748
# 4    825 W. Fulton Mkt  41.886604 -87.648536

# %%
mapping = folium.Map(location = [41.895558	, -87.679967],
                    zoom_start = 11
)

for idx, row in df.iterrows():
    if not row["Address"] == "Multiple location":
        folium.Marker(
            location = [row["lat"], row["lng"]],
            popup = row["Cafe"],
            tooltip = row["Menu"],
            icon = folium.Icon(
                icon = "coffee",
                prefix = "fa"
            )
        ).add_to(mapping)

mapping
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
