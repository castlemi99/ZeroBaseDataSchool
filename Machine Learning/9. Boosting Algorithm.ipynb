# %%
import pandas as pd

wine_url = 'https://raw.githubusercontent.com/PinkWink/ML_tutorial/master/dataset/wine.csv'

wine = pd.read_csv(wine_url, index_col=0)

# 맛 등급 컬럼 추가

wine['taste'] = [1 if grade > 5 else 0 for grade in wine['quality']]

X = wine.drop(['taste', 'quality'], axis = 1)
y = wine['taste']

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_sc = sc.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_sc, y , test_size= 0.2, random_state=13)

# %%
import matplotlib.pyplot as plt

wine.hist(bins = 10, figsize=(15,10))
# Out:
# array([[<Axes: title={'center': 'fixed acidity'}>,
#         <Axes: title={'center': 'volatile acidity'}>,
#         <Axes: title={'center': 'citric acid'}>,
#         <Axes: title={'center': 'residual sugar'}>],
#        [<Axes: title={'center': 'chlorides'}>,
#         <Axes: title={'center': 'free sulfur dioxide'}>,
#         <Axes: title={'center': 'total sulfur dioxide'}>,
#         <Axes: title={'center': 'density'}>],
#        [<Axes: title={'center': 'pH'}>,
#         <Axes: title={'center': 'sulphates'}>,
#         <Axes: title={'center': 'alcohol'}>,
#         <Axes: title={'center': 'quality'}>],
#        [<Axes: title={'center': 'color'}>,
#         <Axes: title={'center': 'taste'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
# quality별 특성을 확인해보자.

column_names = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol']

df_pivot_table = wine.pivot_table(column_names, ['quality'], aggfunc = 'median')
df_pivot_table
# Out:
#          alcohol  chlorides  citric acid   density  fixed acidity  \
# quality
# 3          10.15     0.0550         0.33  0.995900           7.45
# 4          10.00     0.0505         0.26  0.994995           7.00
# 5           9.60     0.0530         0.30  0.996100           7.10
# 6          10.50     0.0460         0.31  0.994700           6.90
# 7          11.40     0.0390         0.32  0.992400           6.90
# 8          12.00     0.0370         0.32  0.991890           6.80
# 9          12.50     0.0310         0.36  0.990300           7.10
#
#          free sulfur dioxide     pH  residual sugar  sulphates  \
# quality
# 3                       17.0  3.245            3.15      0.505
# 4                       15.0  3.220            2.20      0.485
# 5                       27.0  3.190            3.00      0.500
# 6                       29.0  3.210            3.10      0.510
# 7                       30.0  3.220            2.80      0.520
# 8                       34.0  3.230            4.10      0.480
# 9                       28.0  3.280            2.20      0.460
#
#          total sulfur dioxide  volatile acidity
# quality
# 3                       102.5             0.415
# 4                       102.0             0.380
# 5                       127.0             0.330
# 6                       117.0             0.270
# 7                       114.0             0.270
# 8                       118.0             0.280
# 9                       119.0             0.270

# %%
corr_matrix = wine.corr()

# quality변수와의 상관계수
corr_matrix['quality'].sort_values(ascending=False)
# Out:
# quality                 1.000000
# taste                   0.814484
# alcohol                 0.444319
# citric acid             0.085532
# free sulfur dioxide     0.055463
# sulphates               0.038485
# pH                      0.019506
# residual sugar         -0.036980
# total sulfur dioxide   -0.041385
# fixed acidity          -0.076743
# color                  -0.119323
# chlorides              -0.200666
# volatile acidity       -0.265699
# density                -0.305858
# Name: quality, dtype: float64

# %%
wine['taste']
# Out:
# 0       0
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 4893    1
# 4894    0
# 4895    1
# 4896    1
# 4897    1
# Name: taste, Length: 6497, dtype: int64

# %%
import seaborn as sns

sns.countplot(x = wine['taste'])
plt.show()

# %% [markdown]
# ## 모델링
#
# 여러 모델들에 대해 한 번에 학습시키고 평가하고 싶다면 아래 방법을 사용하면 된다.

# %%
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier, RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression

models = []
models.append( ('AdaBoostClassifier', AdaBoostClassifier()))
models.append( ('GradientBoostingClassifier', GradientBoostingClassifier()))
models.append( ('RandomForestClassifier', RandomForestClassifier()))
models.append( ('DecisionTreeClassifier', DecisionTreeClassifier()))
models.append( ('LogisticRegression', LogisticRegression()))

# %%
# 교차검증을 실시하며 각 모델의 성능을 저장함

from sklearn.model_selection import KFold, cross_val_score

results = []
names = []

for name, model in models:
    kfold = KFold(n_splits=5, random_state=13, shuffle= True) # shuffle : 데이터 분할 전 데이터를 섞어라.
    cv_results = cross_val_score(model, X_train, y_train, cv = kfold, scoring='accuracy')

    results.append(cv_results)
    names.append(name)

    print(name, cv_results.mean(), cv_results.std())
# Out:
# AdaBoostClassifier 0.7533103205745169 0.02644765901536818
# GradientBoostingClassifier 0.7665884356259718 0.021614689094861146
# RandomForestClassifier 0.8181566965277265 0.020905505388093725
# DecisionTreeClassifier 0.7517772266232324 0.009726498717007525
# LogisticRegression 0.74273191678389 0.015548839626296565

# %%
# 교차검증 결과 한 눈에 보기

fig = plt.figure(figsize=(14, 8))
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()

# %% [markdown]
# 와인 데이터에서는 RandomForest가 성능이 제일 좋아보인다.
#
# 각 데이터의 특성에 따라 모델들의 성능은 달라진다.

# %%
# 테스트 데이터에 대한 성능 평가

from sklearn.metrics import accuracy_score

for name, model in models:
    model.fit(X_train, y_train)
    pred = model.predict(X_test)
    print(name, accuracy_score(y_test, pred))
# Out:
# AdaBoostClassifier 0.7553846153846154
# GradientBoostingClassifier 0.7884615384615384
# RandomForestClassifier 0.8415384615384616
# DecisionTreeClassifier 0.7746153846153846
# LogisticRegression 0.7469230769230769

# %% [markdown]
# ## KNN

# %%
from sklearn.datasets import load_iris

iris = load_iris()

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.2,
                                                    stratify=iris.target)

# %% [markdown]
# KNN은 그냥 주어진 데이터로부터 가장 가까운 클래스가 무엇인지 찾는 과정이기 때문에 이전 모델과 같이 실제로 학습(fit)을 하지는 않는다. 하지만 sklearn 상 fit을 시켜주어야하기 때문에 코드는 실행시켜주어야한다.

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
from sklearn.metrics import accuracy_score

pred = knn.predict(X_test)
accuracy_score(y_test, pred)
# Out:
# 0.9666666666666667

# %%
from sklearn.metrics import classification_report, confusion_matrix

confusion_matrix(y_test, pred)
# Out:
# array([[10,  0,  0],
#        [ 0,  9,  1],
#        [ 0,  0, 10]], dtype=int64)

# %%
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      0.90      0.95        10
#            2       0.91      1.00      0.95        10
#
#     accuracy                           0.97        30
#    macro avg       0.97      0.97      0.97        30
# weighted avg       0.97      0.97      0.97        30

# %% [markdown]
# ## GBM

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/PinkWink/ML_tutorial/master/dataset/HAR_dataset/features.txt'

# \s+ : 공백 문자(스페이스, 탭, 개행 등)
feature_name_df = pd.read_csv(url, sep = '\s+', header = None,
                              names = ['column_index', 'column_name'])
feature_name = feature_name_df.iloc[:,1].values.tolist() # 리스트 형태로 바꿔줌

X_train_url = 'https://raw.githubusercontent.com/PinkWink/ML_tutorial/master/dataset/HAR_dataset/train/X_train.txt'
X_test_url = 'https://raw.githubusercontent.com/PinkWink/ML_tutorial/master/dataset/HAR_dataset/test/X_test.txt'

X_train = pd.read_csv(X_train_url, sep = '\s+', header = None)
X_test = pd.read_csv(X_test_url, sep = '\s+', header = None)

X_train.columns = feature_name
X_test.columns = feature_name

# %%
y_train_url = 'https://raw.githubusercontent.com/PinkWink/ML_tutorial/master/dataset/HAR_dataset/train/y_train.txt'
y_test_url = 'https://raw.githubusercontent.com/PinkWink/ML_tutorial/master/dataset/HAR_dataset/test/y_test.txt'

y_train = pd.read_csv(y_train_url, sep = '\s+', header = None, names = ['action'])
y_test = pd.read_csv(y_test_url, sep = '\s+', header = None, names = ['action'])

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score

gb_clf = GradientBoostingClassifier(random_state=13)
gb_clf.fit(X_train, y_train)
gb_pred = gb_clf.predict(X_test)

accuracy_score(y_test, gb_pred)

# %% [markdown]
# 일반적으로 GBM의 성능 자체는 랜덤포레스트보단 좋다고 알려져있다. 하지만 속도가 매우 느린 것이 단점이다.

# %%
# GridSearch
from sklearn.model_selection import GridSearchCV

params = {
    'n_estimators' : [100,500],
    'learning_rate' : [0.05, 0.1]
}

## verbose 옵션 : 수행 결과 메세지 출력 여부
## 0(default) : 출력 x, 1 : 간단한 메세지 출력, 2 : 하이퍼파라미터별 메세지 출력
grid = GridSearchCV(gb_clf, param_grid=params, cv = 2, verbose=2, n_jobs=-1)
grid.fit(X_train, y_train)

# %%
accuracy_score(y_test, grid.best_estimator_.predict(X_test))

# %% [markdown]
# ## XGBoost

# %%
#!pip install xgboost
# Out:
# Collecting xgboost
#   Obtaining dependency information for xgboost from https://files.pythonhosted.org/packages/32/10/4689bda37403f7dd029d550c4446e0097c2f33b8ae877b235e76d5c49bc2/xgboost-2.0.0-py3-none-win_amd64.whl.metadata
#   Downloading xgboost-2.0.0-py3-none-win_amd64.whl.metadata (2.0 kB)
# Requirement already satisfied: numpy in c:\users\nabi4\anaconda3\envs\ds_study\lib\site-packages (from xgboost) (1.24.3)
# Requirement already satisfied: scipy in c:\users\nabi4\anaconda3\envs\ds_study\lib\site-packages (from xgboost) (1.10.1)
# Downloading xgboost-2.0.0-py3-none-win_amd64.whl (99.7 MB)
#    ---------------------------------------- 0.0/99.7 MB ? eta -:--:--
#    ---------------------------------------- 0.1/99.7 MB 1.7 MB/s eta 0:00:58
#    ---------------------------------------- 0.2/99.7 MB 2.1 MB/s eta 0:00:49
#    ---------------------------------------- 0.4/99.7 MB 2.5 MB/s eta 0:00:40
#    ---------------------------------------- 0.4/99.7 MB 2.1 MB/s eta 0:00:49
#    ---------------------------------------- 0.5/99.7 MB 2.1 MB/s eta 0:00:47
#    ---------------------------------------- 0.6/99.7 MB 2.1 MB/s eta 0:00:48
#    ---------------------------------------- 0.6/99.7 MB 1.9 MB/s eta 0:00:52
#    ---------------------------------------- 0.7/99.7 MB 1.9 MB/s eta 0:00:52
#    ---------------------------------------- 0.8/99.7 MB 2.0 MB/s eta 0:00:51
#    ---------------------------------------- 0.9/99.7 MB 1.8 MB/s eta 0:00:55
#    ---------------------------------------- 1.0/99.7 MB 1.8 MB/s eta 0:00:55
#    ---------------------------------------- 1.0/99.7 MB 1.7 MB/s eta 0:00:59
#    ---------------------------------------- 1.1/99.7 MB 1.7 MB/s eta 0:01:00
#    ---------------------------------------- 1.2/99.7 MB 1.7 MB/s eta 0:01:00
#     --------------------------------------- 1.3/99.7 MB 1.8 MB/s eta 0:00:55
#     --------------------------------------- 1.3/99.7 MB 1.7 MB/s eta 0:00:57
#     --------------------------------------- 1.3/99.7 MB 1.7 MB/s eta 0:00:57
#     --------------------------------------- 1.3/99.7 MB 1.7 MB/s eta 0:00:57
#     --------------------------------------- 1.4/99.7 MB 1.6 MB/s eta 0:01:04
#     --------------------------------------- 1.6/99.7 MB 1.6 MB/s eta 0:01:00
#     --------------------------------------- 1.6/99.7 MB 1.6 MB/s eta 0:01:01
#     --------------------------------------- 1.7/99.7 MB 1.6 MB/s eta 0:01:03
#     --------------------------------------- 1.8/99.7 MB 1.6 MB/s eta 0:01:01
#     --------------------------------------- 1.9/99.7 MB 1.6 MB/s eta 0:01:02
#     --------------------------------------- 2.0/99.7 MB 1.6 MB/s eta 0:01:01
#     --------------------------------------- 2.1/99.7 MB 1.7 MB/s eta 0:00:58
#     --------------------------------------- 2.3/99.7 MB 1.7 MB/s eta 0:00:57
#     --------------------------------------- 2.4/99.7 MB 1.8 MB/s eta 0:00:56
#    - -------------------------------------- 2.6/99.7 MB 1.8 MB/s eta 0:00:53
#    - -------------------------------------- 2.7/99.7 MB 1.8 MB/s eta 0:00:53
#    - -------------------------------------- 3.0/99.7 MB 2.0 MB/s eta 0:00:50
#    - -------------------------------------- 3.1/99.7 MB 2.0 MB/s eta 0:00:48
#    - -------------------------------------- 3.3/99.7 MB 2.1 MB/s eta 0:00:47
#    - -------------------------------------- 3.6/99.7 MB 2.2 MB/s eta 0:00:45
#    - -------------------------------------- 3.8/99.7 MB 2.3 MB/s eta 0:00:43
#    - -------------------------------------- 4.1/99.7 MB 2.3 MB/s eta 0:00:41
#    - -------------------------------------- 4.3/99.7 MB 2.4 MB/s eta 0:00:40
#    - -------------------------------------- 4.6/99.7 MB 2.5 MB/s eta 0:00:38
#    - -------------------------------------- 4.8/99.7 MB 2.6 MB/s eta 0:00:37
#    -- ------------------------------------- 5.1/99.7 MB 2.7 MB/s eta 0:00:36
#    -- ------------------------------------- 5.3/99.7 MB 2.7 MB/s eta 0:00:35
#    -- ------------------------------------- 5.7/99.7 MB 2.8 MB/s eta 0:00:34
#    -- ------------------------------------- 5.8/99.7 MB 2.8 MB/s eta 0:00:34
#    -- ------------------------------------- 6.0/99.7 MB 2.8 MB/s eta 0:00:34
#    -- ------------------------------------- 6.3/99.7 MB 2.9 MB/s eta 0:00:33
#    -- ------------------------------------- 6.5/99.7 MB 2.9 MB/s eta 0:00:32
#    -- ------------------------------------- 6.8/99.7 MB 3.0 MB/s eta 0:00:32
#    -- ------------------------------------- 7.1/99.7 MB 3.0 MB/s eta 0:00:31
#    -- ------------------------------------- 7.4/99.7 MB 3.1 MB/s eta 0:00:30
#    --- ------------------------------------ 7.7/99.7 MB 3.2 MB/s eta 0:00:29
#    --- ------------------------------------ 7.9/99.7 MB 3.2 MB/s eta 0:00:29
#    --- ------------------------------------ 8.4/99.7 MB 3.3 MB/s eta 0:00:28
#    --- ------------------------------------ 8.5/99.7 MB 3.3 MB/s eta 0:00:28
#    --- ------------------------------------ 8.8/99.7 MB 3.4 MB/s eta 0:00:28
#    --- ------------------------------------ 9.1/99.7 MB 3.4 MB/s eta 0:00:27
#    --- ------------------------------------ 9.4/99.7 MB 3.5 MB/s eta 0:00:26
#    --- ------------------------------------ 9.9/99.7 MB 3.6 MB/s eta 0:00:26
#    ---- ----------------------------------- 10.4/99.7 MB 3.7 MB/s eta 0:00:24
#    ---- ----------------------------------- 10.8/99.7 MB 4.0 MB/s eta 0:00:23
#    ---- ----------------------------------- 11.1/99.7 MB 4.3 MB/s eta 0:00:21
#    ---- ----------------------------------- 11.4/99.7 MB 4.5 MB/s eta 0:00:20
#    ---- ----------------------------------- 11.8/99.7 MB 5.0 MB/s eta 0:00:18
#    ---- ----------------------------------- 12.2/99.7 MB 5.6 MB/s eta 0:00:16
#    ----- ---------------------------------- 12.7/99.7 MB 6.0 MB/s eta 0:00:15
#    ----- ---------------------------------- 13.1/99.7 MB 6.1 MB/s eta 0:00:15
#    ----- ---------------------------------- 13.5/99.7 MB 6.3 MB/s eta 0:00:14
#    ----- ---------------------------------- 13.8/99.7 MB 6.4 MB/s eta 0:00:14
#    ----- ---------------------------------- 14.3/99.7 MB 6.7 MB/s eta 0:00:13
#    ----- ---------------------------------- 14.7/99.7 MB 6.8 MB/s eta 0:00:13
#    ------ --------------------------------- 15.0/99.7 MB 6.7 MB/s eta 0:00:13
#    ------ --------------------------------- 15.3/99.7 MB 6.8 MB/s eta 0:00:13
#    ------ --------------------------------- 15.9/99.7 MB 7.0 MB/s eta 0:00:12
#    ------ --------------------------------- 16.1/99.7 MB 7.2 MB/s eta 0:00:12
#    ------ --------------------------------- 16.3/99.7 MB 7.2 MB/s eta 0:00:12
#    ------ --------------------------------- 16.4/99.7 MB 7.1 MB/s eta 0:00:12
#    ------ --------------------------------- 16.7/99.7 MB 7.0 MB/s eta 0:00:12
#    ------ --------------------------------- 17.1/99.7 MB 7.2 MB/s eta 0:00:12
#    ------- -------------------------------- 17.5/99.7 MB 7.3 MB/s eta 0:00:12
#    ------- -------------------------------- 18.1/99.7 MB 7.4 MB/s eta 0:00:12
#    ------- -------------------------------- 18.3/99.7 MB 7.7 MB/s eta 0:00:11
#    ------- -------------------------------- 18.4/99.7 MB 7.4 MB/s eta 0:00:12
#    ------- -------------------------------- 19.5/99.7 MB 8.0 MB/s eta 0:00:11
#    -------- ------------------------------- 20.0/99.7 MB 8.0 MB/s eta 0:00:10
#    -------- ------------------------------- 20.4/99.7 MB 8.0 MB/s eta 0:00:10
#    -------- ------------------------------- 21.0/99.7 MB 8.2 MB/s eta 0:00:10
#    -------- ------------------------------- 21.3/99.7 MB 8.2 MB/s eta 0:00:10
#    -------- ------------------------------- 21.7/99.7 MB 8.2 MB/s eta 0:00:10
#    -------- ------------------------------- 22.3/99.7 MB 8.3 MB/s eta 0:00:10
#    --------- ------------------------------ 22.8/99.7 MB 8.4 MB/s eta 0:00:10
#    --------- ------------------------------ 23.3/99.7 MB 8.5 MB/s eta 0:00:09
#    --------- ------------------------------ 23.7/99.7 MB 8.4 MB/s eta 0:00:10
#    --------- ------------------------------ 24.1/99.7 MB 8.6 MB/s eta 0:00:09
#    --------- ------------------------------ 24.3/99.7 MB 8.3 MB/s eta 0:00:10
#    --------- ------------------------------ 24.5/99.7 MB 8.2 MB/s eta 0:00:10
#    --------- ------------------------------ 24.7/99.7 MB 8.1 MB/s eta 0:00:10
#    --------- ------------------------------ 24.7/99.7 MB 8.0 MB/s eta 0:00:10
#    --------- ------------------------------ 24.8/99.7 MB 7.5 MB/s eta 0:00:10
#    ---------- ----------------------------- 25.4/99.7 MB 7.8 MB/s eta 0:00:10
#    ---------- ----------------------------- 25.6/99.7 MB 7.7 MB/s eta 0:00:10
#    ---------- ----------------------------- 25.9/99.7 MB 7.6 MB/s eta 0:00:10
#    ---------- ----------------------------- 26.1/99.7 MB 7.4 MB/s eta 0:00:11
#    ---------- ----------------------------- 26.4/99.7 MB 7.4 MB/s eta 0:00:10
#    ---------- ----------------------------- 26.5/99.7 MB 7.5 MB/s eta 0:00:10
#    ---------- ----------------------------- 26.8/99.7 MB 7.5 MB/s eta 0:00:10
#    ---------- ----------------------------- 26.9/99.7 MB 7.5 MB/s eta 0:00:10
#    ---------- ----------------------------- 26.9/99.7 MB 7.5 MB/s eta 0:00:10
#    ---------- ----------------------------- 26.9/99.7 MB 7.5 MB/s eta 0:00:10
#    ----------- ---------------------------- 27.9/99.7 MB 7.2 MB/s eta 0:00:10
#    ----------- ---------------------------- 28.2/99.7 MB 7.0 MB/s eta 0:00:11
#    ----------- ---------------------------- 28.6/99.7 MB 7.2 MB/s eta 0:00:10
#    ----------- ---------------------------- 29.0/99.7 MB 7.0 MB/s eta 0:00:11
#    ----------- ---------------------------- 29.4/99.7 MB 6.9 MB/s eta 0:00:11
#    ----------- ---------------------------- 29.8/99.7 MB 7.0 MB/s eta 0:00:11
#    ------------ --------------------------- 30.4/99.7 MB 7.0 MB/s eta 0:00:10
#    ------------ --------------------------- 30.7/99.7 MB 6.9 MB/s eta 0:00:11
#    ------------ --------------------------- 31.3/99.7 MB 7.0 MB/s eta 0:00:10
#    ------------ --------------------------- 31.9/99.7 MB 7.2 MB/s eta 0:00:10
#    ------------ --------------------------- 32.4/99.7 MB 7.0 MB/s eta 0:00:10
#    ------------- -------------------------- 32.8/99.7 MB 7.1 MB/s eta 0:00:10
#    ------------- -------------------------- 33.5/99.7 MB 7.1 MB/s eta 0:00:10
#    ------------- -------------------------- 34.2/99.7 MB 7.2 MB/s eta 0:00:10
#    ------------- -------------------------- 34.5/99.7 MB 7.3 MB/s eta 0:00:09
#    -------------- ------------------------- 35.1/99.7 MB 8.1 MB/s eta 0:00:09
#    -------------- ------------------------- 35.5/99.7 MB 8.2 MB/s eta 0:00:08
#    -------------- ------------------------- 36.0/99.7 MB 8.4 MB/s eta 0:00:08
#    -------------- ------------------------- 36.3/99.7 MB 8.6 MB/s eta 0:00:08
#    -------------- ------------------------- 36.6/99.7 MB 8.6 MB/s eta 0:00:08
#    -------------- ------------------------- 37.1/99.7 MB 9.0 MB/s eta 0:00:07
#    --------------- ------------------------ 37.6/99.7 MB 9.6 MB/s eta 0:00:07
#    --------------- ------------------------ 38.1/99.7 MB 9.6 MB/s eta 0:00:07
#    --------------- ------------------------ 38.4/99.7 MB 9.6 MB/s eta 0:00:07
#    --------------- ------------------------ 38.9/99.7 MB 10.1 MB/s eta 0:00:07
#    --------------- ------------------------ 39.4/99.7 MB 9.8 MB/s eta 0:00:07
#    --------------- ------------------------ 39.8/99.7 MB 9.6 MB/s eta 0:00:07
#    ---------------- ----------------------- 40.1/99.7 MB 9.5 MB/s eta 0:00:07
#    ---------------- ----------------------- 40.4/99.7 MB 9.1 MB/s eta 0:00:07
#    ---------------- ----------------------- 40.7/99.7 MB 9.1 MB/s eta 0:00:07
#    ---------------- ----------------------- 40.9/99.7 MB 9.0 MB/s eta 0:00:07
#    ---------------- ----------------------- 41.1/99.7 MB 8.7 MB/s eta 0:00:07
#    ---------------- ----------------------- 41.6/99.7 MB 8.6 MB/s eta 0:00:07
#    ---------------- ----------------------- 41.9/99.7 MB 8.5 MB/s eta 0:00:07
#    ---------------- ----------------------- 42.4/99.7 MB 8.5 MB/s eta 0:00:07
#    ----------------- ---------------------- 42.7/99.7 MB 8.4 MB/s eta 0:00:07
#    ----------------- ---------------------- 43.3/99.7 MB 8.4 MB/s eta 0:00:07
#    ----------------- ---------------------- 43.5/99.7 MB 8.3 MB/s eta 0:00:07
#    ----------------- ---------------------- 44.3/99.7 MB 8.3 MB/s eta 0:00:07
#    ----------------- ---------------------- 44.9/99.7 MB 8.4 MB/s eta 0:00:07
#    ------------------ --------------------- 45.5/99.7 MB 8.4 MB/s eta 0:00:07
#    ------------------ --------------------- 46.0/99.7 MB 8.3 MB/s eta 0:00:07
#    ------------------ --------------------- 46.6/99.7 MB 8.4 MB/s eta 0:00:07
#    ------------------ --------------------- 47.2/99.7 MB 8.7 MB/s eta 0:00:07
#    ------------------- -------------------- 47.6/99.7 MB 8.8 MB/s eta 0:00:06
#    ------------------- -------------------- 48.1/99.7 MB 8.6 MB/s eta 0:00:06
#    ------------------- -------------------- 48.6/99.7 MB 8.7 MB/s eta 0:00:06
#    ------------------- -------------------- 48.9/99.7 MB 8.7 MB/s eta 0:00:06
#    ------------------- -------------------- 49.3/99.7 MB 8.6 MB/s eta 0:00:06
#    ------------------- -------------------- 49.6/99.7 MB 8.6 MB/s eta 0:00:06
#    -------------------- ------------------- 50.1/99.7 MB 8.8 MB/s eta 0:00:06
#    -------------------- ------------------- 50.4/99.7 MB 8.8 MB/s eta 0:00:06
#    -------------------- ------------------- 50.9/99.7 MB 9.0 MB/s eta 0:00:06
#    -------------------- ------------------- 51.1/99.7 MB 9.0 MB/s eta 0:00:06
#    -------------------- ------------------- 51.3/99.7 MB 8.8 MB/s eta 0:00:06
#    -------------------- ------------------- 51.4/99.7 MB 8.8 MB/s eta 0:00:06
#    -------------------- ------------------- 51.4/99.7 MB 8.8 MB/s eta 0:00:06
#    -------------------- ------------------- 51.4/99.7 MB 8.8 MB/s eta 0:00:06
#    -------------------- ------------------- 51.9/99.7 MB 8.2 MB/s eta 0:00:06
#    -------------------- ------------------- 52.0/99.7 MB 7.9 MB/s eta 0:00:07
#    -------------------- ------------------- 52.1/99.7 MB 7.7 MB/s eta 0:00:07
#    -------------------- ------------------- 52.3/99.7 MB 7.6 MB/s eta 0:00:07
#    --------------------- ------------------ 52.6/99.7 MB 7.4 MB/s eta 0:00:07
#    --------------------- ------------------ 52.8/99.7 MB 7.3 MB/s eta 0:00:07
#    --------------------- ------------------ 53.0/99.7 MB 7.3 MB/s eta 0:00:07
#    --------------------- ------------------ 53.2/99.7 MB 7.0 MB/s eta 0:00:07
#    --------------------- ------------------ 53.4/99.7 MB 7.0 MB/s eta 0:00:07
#    --------------------- ------------------ 53.6/99.7 MB 6.8 MB/s eta 0:00:07
#    --------------------- ------------------ 53.8/99.7 MB 6.7 MB/s eta 0:00:07
#    --------------------- ------------------ 54.2/99.7 MB 6.6 MB/s eta 0:00:07
#    --------------------- ------------------ 54.4/99.7 MB 6.5 MB/s eta 0:00:07
#    --------------------- ------------------ 54.7/99.7 MB 6.4 MB/s eta 0:00:08
#    ---------------------- ----------------- 55.0/99.7 MB 6.4 MB/s eta 0:00:08
#    ---------------------- ----------------- 55.4/99.7 MB 6.3 MB/s eta 0:00:08
#    ---------------------- ----------------- 55.7/99.7 MB 6.2 MB/s eta 0:00:08
#    ---------------------- ----------------- 56.1/99.7 MB 6.2 MB/s eta 0:00:08
#    ---------------------- ----------------- 56.5/99.7 MB 6.2 MB/s eta 0:00:07
#    ---------------------- ----------------- 57.0/99.7 MB 6.2 MB/s eta 0:00:07
#    ---------------------- ----------------- 57.2/99.7 MB 6.1 MB/s eta 0:00:07
#    ----------------------- ---------------- 57.5/99.7 MB 6.0 MB/s eta 0:00:08
#    ----------------------- ---------------- 57.9/99.7 MB 5.8 MB/s eta 0:00:08
#    ----------------------- ---------------- 58.2/99.7 MB 5.8 MB/s eta 0:00:08
#    ----------------------- ---------------- 58.7/99.7 MB 5.8 MB/s eta 0:00:08
#    ----------------------- ---------------- 59.0/99.7 MB 5.7 MB/s eta 0:00:08
#    ----------------------- ---------------- 59.3/99.7 MB 5.7 MB/s eta 0:00:08
#    ----------------------- ---------------- 59.4/99.7 MB 5.6 MB/s eta 0:00:08
#    ----------------------- ---------------- 59.8/99.7 MB 5.7 MB/s eta 0:00:08
#    ------------------------ --------------- 60.2/99.7 MB 5.6 MB/s eta 0:00:08
#    ------------------------ --------------- 60.7/99.7 MB 5.8 MB/s eta 0:00:07
#    ------------------------ --------------- 61.4/99.7 MB 6.0 MB/s eta 0:00:07
#    ------------------------ --------------- 61.9/99.7 MB 6.5 MB/s eta 0:00:06
#    ------------------------- -------------- 62.4/99.7 MB 6.9 MB/s eta 0:00:06
#    ------------------------- -------------- 63.0/99.7 MB 7.3 MB/s eta 0:00:06
#    ------------------------- -------------- 63.5/99.7 MB 7.8 MB/s eta 0:00:05
#    ------------------------- -------------- 64.2/99.7 MB 8.4 MB/s eta 0:00:05
#    -------------------------- ------------- 65.0/99.7 MB 9.0 MB/s eta 0:00:04
#    -------------------------- ------------- 65.8/99.7 MB 9.2 MB/s eta 0:00:04
#    -------------------------- ------------- 66.2/99.7 MB 9.5 MB/s eta 0:00:04
#    -------------------------- ------------- 66.7/99.7 MB 9.5 MB/s eta 0:00:04
#    -------------------------- ------------- 67.2/99.7 MB 9.4 MB/s eta 0:00:04
#    --------------------------- ------------ 67.8/99.7 MB 9.9 MB/s eta 0:00:04
#    --------------------------- ------------ 68.3/99.7 MB 10.4 MB/s eta 0:00:04
#    --------------------------- ------------ 68.8/99.7 MB 10.6 MB/s eta 0:00:03
#    --------------------------- ------------ 69.1/99.7 MB 10.4 MB/s eta 0:00:03
#    --------------------------- ------------ 69.6/99.7 MB 11.1 MB/s eta 0:00:03
#    ---------------------------- ----------- 70.1/99.7 MB 11.5 MB/s eta 0:00:03
#    ---------------------------- ----------- 70.6/99.7 MB 11.3 MB/s eta 0:00:03
#    ---------------------------- ----------- 71.0/99.7 MB 10.9 MB/s eta 0:00:03
#    ---------------------------- ----------- 71.4/99.7 MB 10.7 MB/s eta 0:00:03
#    ---------------------------- ----------- 71.7/99.7 MB 10.6 MB/s eta 0:00:03
#    ---------------------------- ----------- 72.1/99.7 MB 10.4 MB/s eta 0:00:03
#    ----------------------------- ---------- 72.5/99.7 MB 10.2 MB/s eta 0:00:03
#    ----------------------------- ---------- 72.9/99.7 MB 10.1 MB/s eta 0:00:03
#    ----------------------------- ---------- 73.2/99.7 MB 9.8 MB/s eta 0:00:03
#    ----------------------------- ---------- 73.5/99.7 MB 9.8 MB/s eta 0:00:03
#    ----------------------------- ---------- 73.8/99.7 MB 9.5 MB/s eta 0:00:03
#    ----------------------------- ---------- 74.1/99.7 MB 9.2 MB/s eta 0:00:03
#    ----------------------------- ---------- 74.4/99.7 MB 9.2 MB/s eta 0:00:03
#    ----------------------------- ---------- 74.6/99.7 MB 8.8 MB/s eta 0:00:03
#    ------------------------------ --------- 75.2/99.7 MB 8.7 MB/s eta 0:00:03
#    ------------------------------ --------- 75.6/99.7 MB 8.6 MB/s eta 0:00:03
#    ------------------------------ --------- 76.0/99.7 MB 8.5 MB/s eta 0:00:03
#    ------------------------------ --------- 76.3/99.7 MB 8.4 MB/s eta 0:00:03
#    ------------------------------ --------- 76.7/99.7 MB 8.4 MB/s eta 0:00:03
#    ------------------------------ --------- 77.1/99.7 MB 8.4 MB/s eta 0:00:03
#    ------------------------------- -------- 77.4/99.7 MB 8.2 MB/s eta 0:00:03
#    ------------------------------- -------- 77.7/99.7 MB 8.1 MB/s eta 0:00:03
#    ------------------------------- -------- 78.2/99.7 MB 8.1 MB/s eta 0:00:03
#    ------------------------------- -------- 78.6/99.7 MB 8.0 MB/s eta 0:00:03
#    ------------------------------- -------- 78.8/99.7 MB 7.9 MB/s eta 0:00:03
#    ------------------------------- -------- 79.2/99.7 MB 7.8 MB/s eta 0:00:03
#    ------------------------------- -------- 79.6/99.7 MB 7.6 MB/s eta 0:00:03
#    -------------------------------- ------- 80.2/99.7 MB 7.5 MB/s eta 0:00:03
#    -------------------------------- ------- 80.6/99.7 MB 7.5 MB/s eta 0:00:03
#    -------------------------------- ------- 81.0/99.7 MB 7.5 MB/s eta 0:00:03
#    -------------------------------- ------- 81.4/99.7 MB 7.6 MB/s eta 0:00:03
#    -------------------------------- ------- 81.8/99.7 MB 7.6 MB/s eta 0:00:03
#    --------------------------------- ------ 82.5/99.7 MB 7.8 MB/s eta 0:00:03
#    --------------------------------- ------ 83.0/99.7 MB 7.9 MB/s eta 0:00:03
#    --------------------------------- ------ 83.4/99.7 MB 8.1 MB/s eta 0:00:03
#    --------------------------------- ------ 83.9/99.7 MB 8.2 MB/s eta 0:00:02
#    --------------------------------- ------ 84.3/99.7 MB 8.3 MB/s eta 0:00:02
#    ---------------------------------- ----- 85.0/99.7 MB 8.7 MB/s eta 0:00:02
#    ---------------------------------- ----- 85.5/99.7 MB 8.8 MB/s eta 0:00:02
#    ---------------------------------- ----- 86.0/99.7 MB 9.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 86.6/99.7 MB 9.1 MB/s eta 0:00:02
#    ----------------------------------- ---- 87.3/99.7 MB 9.2 MB/s eta 0:00:02
#    ----------------------------------- ---- 87.8/99.7 MB 9.6 MB/s eta 0:00:02
#    ----------------------------------- ---- 88.4/99.7 MB 9.5 MB/s eta 0:00:02
#    ----------------------------------- ---- 88.8/99.7 MB 9.5 MB/s eta 0:00:02
#    ----------------------------------- ---- 89.1/99.7 MB 9.9 MB/s eta 0:00:02
#    ----------------------------------- ---- 89.7/99.7 MB 10.1 MB/s eta 0:00:01
#    ------------------------------------ --- 90.2/99.7 MB 10.2 MB/s eta 0:00:01
#    ------------------------------------ --- 90.6/99.7 MB 10.4 MB/s eta 0:00:01
#    ------------------------------------ --- 91.2/99.7 MB 10.6 MB/s eta 0:00:01
#    ------------------------------------ --- 91.5/99.7 MB 10.4 MB/s eta 0:00:01
#    ------------------------------------ --- 91.7/99.7 MB 10.1 MB/s eta 0:00:01
#    ------------------------------------ --- 92.0/99.7 MB 10.1 MB/s eta 0:00:01
#    ------------------------------------- -- 92.3/99.7 MB 9.9 MB/s eta 0:00:01
#    ------------------------------------- -- 92.6/99.7 MB 9.8 MB/s eta 0:00:01
#    ------------------------------------- -- 93.1/99.7 MB 9.6 MB/s eta 0:00:01
#    ------------------------------------- -- 93.7/99.7 MB 9.5 MB/s eta 0:00:01
#    ------------------------------------- -- 94.2/99.7 MB 9.4 MB/s eta 0:00:01
#    ------------------------------------- -- 94.7/99.7 MB 9.4 MB/s eta 0:00:01
#    -------------------------------------- - 95.1/99.7 MB 9.2 MB/s eta 0:00:01
#    -------------------------------------- - 95.4/99.7 MB 9.1 MB/s eta 0:00:01
#    -------------------------------------- - 95.9/99.7 MB 9.0 MB/s eta 0:00:01
#    -------------------------------------- - 96.4/99.7 MB 9.1 MB/s eta 0:00:01
#    -------------------------------------- - 97.1/99.7 MB 9.2 MB/s eta 0:00:01
#    ---------------------------------------  97.7/99.7 MB 9.2 MB/s eta 0:00:01
#    ---------------------------------------  98.1/99.7 MB 9.4 MB/s eta 0:00:01
#    ---------------------------------------  98.6/99.7 MB 9.2 MB/s eta 0:00:01
#    ---------------------------------------  99.2/99.7 MB 9.4 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.7 MB 9.4 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.7 MB 9.4 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.7 MB 9.4 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.7 MB 9.4 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.7 MB 9.4 MB/s eta 0:00:01
#    ---------------------------------------- 99.7/99.7 MB 7.5 MB/s eta 0:00:00
# Installing collected packages: xgboost
# Successfully installed xgboost-2.0.0

# %%
# https://velog.io/@theo/xgboost-%EC%83%88-%EB%B2%84%EC%A0%84%EC%97%90%EC%84%9C-%EC%83%9D%EA%B8%B4-%EC%98%A4%EB%A5%98
# ValueError: Invalid classes inferred from unique values of `y`. 에러 해결

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_train = le.fit_transform(y_train)
y_test = le.fit_transform(y_test)
# Out:
# c:\Users\nabi4\anaconda3\envs\ds_study\lib\site-packages\sklearn\preprocessing\_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\nabi4\anaconda3\envs\ds_study\lib\site-packages\sklearn\preprocessing\_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
y_train
# Out:
# array([4, 4, 4, ..., 1, 1, 1], dtype=int64)

# %%
from xgboost import XGBClassifier

xgb = XGBClassifier(n_estimators = 400, learning_rate = 0.1, max_depth=3)
xgb.fit(X_train.values, y_train) # xgboost에는 numpy values값의 형태로 넣어주어야한다.

accuracy_score(y_test, xgb.predict(X_test))
# Out:
# 0.9497794367153037

# %%
# 조기 종료 조건과 검증 데이터 지정

evals = [(X_test.values, y_test)] # 검증 데이터 셋. 이번 실습에서는 테스트 셋을 검증 셋으로 설정했다.

xgb = XGBClassifier(n_estimators = 400, learning_rate = 0.1, max_depth=3)
xgb.fit(X_train.values, y_train, early_stopping_rounds=10, eval_set=evals)
# eval_set: 평가를 수행하는 별도의 검증 데이터 세트.
# early_stopping_rounds: 조기 중단할 수 있는 최소 반복 횟수
# Out:
# c:\Users\nabi4\anaconda3\envs\ds_study\lib\site-packages\xgboost\sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-mlogloss:1.58912
# [1]	validation_0-mlogloss:1.43298
# [2]	validation_0-mlogloss:1.30579
# [3]	validation_0-mlogloss:1.19398
# [4]	validation_0-mlogloss:1.10151
# [5]	validation_0-mlogloss:1.01952
# [6]	validation_0-mlogloss:0.94821
# [7]	validation_0-mlogloss:0.88468
# [8]	validation_0-mlogloss:0.82846
# [9]	validation_0-mlogloss:0.77660
# [10]	validation_0-mlogloss:0.73051
# [11]	validation_0-mlogloss:0.68873
# [12]	validation_0-mlogloss:0.65163
# [13]	validation_0-mlogloss:0.61809
# [14]	validation_0-mlogloss:0.58776
# [15]	validation_0-mlogloss:0.55936
# [16]	validation_0-mlogloss:0.53447
# [17]	validation_0-mlogloss:0.51131
# [18]	validation_0-mlogloss:0.49076
# [19]	validation_0-mlogloss:0.47043
# [20]	validation_0-mlogloss:0.45119
# [21]	validation_0-mlogloss:0.43441
# [22]	validation_0-mlogloss:0.41777
# [23]	validation_0-mlogloss:0.40352
# [24]	validation_0-mlogloss:0.38949
# [25]	validation_0-mlogloss:0.37684
# [26]	validation_0-mlogloss:0.36371
# [27]	validation_0-mlogloss:0.35286
# [28]	validation_0-mlogloss:0.34221
# [29]	validation_0-mlogloss:0.33315
# [30]	validation_0-mlogloss:0.32387
# [31]	validation_0-mlogloss:0.31562
# [32]	validation_0-mlogloss:0.30764
# [33]	validation_0-mlogloss:0.30095
# [34]	validation_0-mlogloss:0.29447
# [35]	validation_0-mlogloss:0.28810
# [36]	validation_0-mlogloss:0.28179
# [37]	validation_0-mlogloss:0.27471
# [38]	validation_0-mlogloss:0.26885
# [39]	validation_0-mlogloss:0.26238
# [40]	validation_0-mlogloss:0.25814
# [41]	validation_0-mlogloss:0.25317
# [42]	validation_0-mlogloss:0.24820
# [43]	validation_0-mlogloss:0.24403
# [44]	validation_0-mlogloss:0.23968
# [45]	validation_0-mlogloss:0.23583
# [46]	validation_0-mlogloss:0.23178
# [47]	validation_0-mlogloss:0.22802
# [48]	validation_0-mlogloss:0.22398
# [49]	validation_0-mlogloss:0.22128
# [50]	validation_0-mlogloss:0.21875
# [51]	validation_0-mlogloss:0.21577
# [52]	validation_0-mlogloss:0.21175
# [53]	validation_0-mlogloss:0.20918
# [54]	validation_0-mlogloss:0.20701
# [55]	validation_0-mlogloss:0.20486
# [56]	validation_0-mlogloss:0.20269
# [57]	validation_0-mlogloss:0.20019
# [58]	validation_0-mlogloss:0.19839
# [59]	validation_0-mlogloss:0.19591
# [60]	validation_0-mlogloss:0.19375
# [61]	validation_0-mlogloss:0.19245
# [62]	validation_0-mlogloss:0.19056
# [63]	validation_0-mlogloss:0.18857
# [64]	validation_0-mlogloss:0.18675
# [65]	validation_0-mlogloss:0.18511
# [66]	validation_0-mlogloss:0.18284
# [67]	validation_0-mlogloss:0.18073
# [68]	validation_0-mlogloss:0.17894
# [69]	validation_0-mlogloss:0.17747
# [70]	validation_0-mlogloss:0.17621
# [71]	validation_0-mlogloss:0.17537
# [72]	validation_0-mlogloss:0.17396
# [73]	validation_0-mlogloss:0.17297
# [74]	validation_0-mlogloss:0.17167
# [75]	validation_0-mlogloss:0.17020
# [76]	validation_0-mlogloss:0.16897
# [77]	validation_0-mlogloss:0.16825
# [78]	validation_0-mlogloss:0.16745
# [79]	validation_0-mlogloss:0.16636
# [80]	validation_0-mlogloss:0.16542
# [81]	validation_0-mlogloss:0.16447
# [82]	validation_0-mlogloss:0.16398
# [83]	validation_0-mlogloss:0.16300
# [84]	validation_0-mlogloss:0.16255
# [85]	validation_0-mlogloss:0.16151
# [86]	validation_0-mlogloss:0.16095
# [87]	validation_0-mlogloss:0.16032
# [88]	validation_0-mlogloss:0.15923
# [89]	validation_0-mlogloss:0.15836
# [90]	validation_0-mlogloss:0.15757
# [91]	validation_0-mlogloss:0.15710
# [92]	validation_0-mlogloss:0.15685
# [93]	validation_0-mlogloss:0.15590
# [94]	validation_0-mlogloss:0.15509
# [95]	validation_0-mlogloss:0.15484
# [96]	validation_0-mlogloss:0.15388
# [97]	validation_0-mlogloss:0.15331
# [98]	validation_0-mlogloss:0.15258
# [99]	validation_0-mlogloss:0.15198
# [100]	validation_0-mlogloss:0.15229
# [101]	validation_0-mlogloss:0.15127
# [102]	validation_0-mlogloss:0.15137
# [103]	validation_0-mlogloss:0.15090
# [104]	validation_0-mlogloss:0.15016
# [105]	validation_0-mlogloss:0.14957
# [106]	validation_0-mlogloss:0.14920
# [107]	validation_0-mlogloss:0.14899
# [108]	validation_0-mlogloss:0.14856
# [109]	validation_0-mlogloss:0.14843
# [110]	validation_0-mlogloss:0.14815
# [111]	validation_0-mlogloss:0.14784
# [112]	validation_0-mlogloss:0.14818
# [113]	validation_0-mlogloss:0.14788
# [114]	validation_0-mlogloss:0.14825
# [115]	validation_0-mlogloss:0.14729
# [116]	validation_0-mlogloss:0.14693
# [117]	validation_0-mlogloss:0.14664
# [118]	validation_0-mlogloss:0.14622
# [119]	validation_0-mlogloss:0.14641
# [120]	validation_0-mlogloss:0.14643
# [121]	validation_0-mlogloss:0.14598
# [122]	validation_0-mlogloss:0.14535
# [123]	validation_0-mlogloss:0.14407
# [124]	validation_0-mlogloss:0.14364
# [125]	validation_0-mlogloss:0.14364
# [126]	validation_0-mlogloss:0.14307
# [127]	validation_0-mlogloss:0.14267
# [128]	validation_0-mlogloss:0.14276
# [129]	validation_0-mlogloss:0.14264
# [130]	validation_0-mlogloss:0.14287
# [131]	validation_0-mlogloss:0.14325
# [132]	validation_0-mlogloss:0.14305
# [133]	validation_0-mlogloss:0.14259
# [134]	validation_0-mlogloss:0.14219
# [135]	validation_0-mlogloss:0.14200
# [136]	validation_0-mlogloss:0.14200
# [137]	validation_0-mlogloss:0.14242
# [138]	validation_0-mlogloss:0.14172
# [139]	validation_0-mlogloss:0.14128
# [140]	validation_0-mlogloss:0.14143
# [141]	validation_0-mlogloss:0.14140
# [142]	validation_0-mlogloss:0.14182
# [143]	validation_0-mlogloss:0.14127
# [144]	validation_0-mlogloss:0.14087
# [145]	validation_0-mlogloss:0.14099
# [146]	validation_0-mlogloss:0.14108
# [147]	validation_0-mlogloss:0.14132
# [148]	validation_0-mlogloss:0.14078
# [149]	validation_0-mlogloss:0.14061
# [150]	validation_0-mlogloss:0.14058
# [151]	validation_0-mlogloss:0.14077
# [152]	validation_0-mlogloss:0.14045
# [153]	validation_0-mlogloss:0.14010
# [154]	validation_0-mlogloss:0.13986
# [155]	validation_0-mlogloss:0.13955
# [156]	validation_0-mlogloss:0.13962
# [157]	validation_0-mlogloss:0.13991
# [158]	validation_0-mlogloss:0.13972
# [159]	validation_0-mlogloss:0.13952
# [160]	validation_0-mlogloss:0.13989
# [161]	validation_0-mlogloss:0.13916
# [162]	validation_0-mlogloss:0.13862
# [163]	validation_0-mlogloss:0.13917
# [164]	validation_0-mlogloss:0.13943
# [165]	validation_0-mlogloss:0.13968
# [166]	validation_0-mlogloss:0.13932
# [167]	validation_0-mlogloss:0.13894
# [168]	validation_0-mlogloss:0.13891
# [169]	validation_0-mlogloss:0.13857
# [170]	validation_0-mlogloss:0.13847
# [171]	validation_0-mlogloss:0.13797
# [172]	validation_0-mlogloss:0.13835
# [173]	validation_0-mlogloss:0.13908
# [174]	validation_0-mlogloss:0.13887
# [175]	validation_0-mlogloss:0.13862
# [176]	validation_0-mlogloss:0.13871
# [177]	validation_0-mlogloss:0.13867
# [178]	validation_0-mlogloss:0.13842
# [179]	validation_0-mlogloss:0.13830
# [180]	validation_0-mlogloss:0.13833
# [181]	validation_0-mlogloss:0.13818
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=400, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
accuracy_score(y_test, xgb.predict(X_test))
# Out:
# 0.9453681710213777

# %% [markdown]
# ## LightGBM

# %%
#!pip install lightgbm
# Out:
# Collecting lightgbm
#   Obtaining dependency information for lightgbm from https://files.pythonhosted.org/packages/b3/f8/ee33e36194eb03a76eccf3adac3fba51f0e56fbd20609bb531659d48d3cb/lightgbm-4.1.0-py3-none-win_amd64.whl.metadata
#   Downloading lightgbm-4.1.0-py3-none-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy in c:\users\nabi4\anaconda3\envs\ds_study\lib\site-packages (from lightgbm) (1.24.3)
# Requirement already satisfied: scipy in c:\users\nabi4\anaconda3\envs\ds_study\lib\site-packages (from lightgbm) (1.10.1)
# Downloading lightgbm-4.1.0-py3-none-win_amd64.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    - -------------------------------------- 0.0/1.3 MB 653.6 kB/s eta 0:00:02
#    --- ------------------------------------ 0.1/1.3 MB 1.2 MB/s eta 0:00:01
#    ------ --------------------------------- 0.2/1.3 MB 1.4 MB/s eta 0:00:01
#    ------- -------------------------------- 0.3/1.3 MB 1.4 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.4/1.3 MB 1.5 MB/s eta 0:00:01
#    -------------- ------------------------- 0.5/1.3 MB 1.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.6/1.3 MB 1.8 MB/s eta 0:00:01
#    --------------------- ------------------ 0.7/1.3 MB 2.0 MB/s eta 0:00:01
#    --------------------------- ------------ 0.9/1.3 MB 2.1 MB/s eta 0:00:01
#    -------------------------------- ------- 1.1/1.3 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------ --- 1.2/1.3 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.3/1.3 MB 2.3 MB/s eta 0:00:00
# Installing collected packages: lightgbm
# Successfully installed lightgbm-4.1.0

# %%
from lightgbm import LGBMClassifier 
evals = [(X_test.values, y_test)] 

lgbm = LGBMClassifier(n_estimators = 400)
lgbm.fit(X_train.values, y_train, early_stopping_rounds=100, eval_set=evals) 


accuracy_score(y_test, lgbm.predict(X_test.values))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\nabi4\ZeroBase\Machine Learning\9. Boosting Algorithm.ipynb Cell 38 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/nabi4/ZeroBase/Machine%20Learning/9.%20Boosting%20Algorithm.ipynb#X52sZmlsZQ%3D%3D?line=1'>2</a> evals = [(X_test.values, y_test)]
#       <a href='vscode-notebook-cell:/c%3A/Users/nabi4/ZeroBase/Machine%20Learning/9.%20Boosting%20Algorithm.ipynb#X52sZmlsZQ%3D%3D?line=3'>4</a> lgbm = LGBMClassifier(n_estimators = 400)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/nabi4/ZeroBase/Machine%20Learning/9.%20Boosting%20Algorithm.ipynb#X52sZmlsZQ%3D%3D?line=4'>5</a> lgbm.fit(X_train.values, y_train, early_stopping_rounds=100, eval_set=evals)
#       <a href='vscode-notebook-cell:/c%3A/Users/nabi4/ZeroBase/Machine%20Learning/9.%20Boosting%20Algorithm.ipynb#X52sZmlsZQ%3D%3D?line=7'>8</a> accuracy_score(y_test, lgbm.predict(X_test.values))
#
# TypeError: fit() got an unexpected keyword argument 'early_stopping_rounds'

# %% [markdown]
# lightgbm에서 조기 종료 조건은 callback 옵션을 사용하는 것 같은데 정확하게 어떻게 사용하는지는 모르겠다ㅠ 하지만 형태는 대강 아래 링크 코드인 것 같다.
#
# https://github.com/optuna/optuna/issues/3145#:~:text=optuna/optuna%20repo.-,Code%20I%20used%3A,-!pip%20install
#
# https://velog.io/@dankj1991/Project-Seoul-FP-Weather-%EB%82%A0%EC%94%A8-%EA%B8%B0%EB%B0%98-%EC%84%9C%EC%9A%B8-%EC%8B%9D%EC%A4%91%EB%8F%85-%ED%99%98%EC%9E%90-%EC%88%98-%EC%98%88%EC%B8%A1-%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%A8-2-Modeling-LightGBM#:~:text=%EB%AA%A8%EB%8D%B8%EB%A7%81%20(early_stopping%3D75)

# %%
lgbm = LGBMClassifier(n_estimators = 400, learning_rate = 0.1, max_depth=3)
lgbm.fit(X_train.values, y_train)

accuracy_score(y_test, lgbm.predict(X_test.values))
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.019197 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140170
# [LightGBM] [Info] Number of data points in the train set: 7352, number of used features: 561
# [LightGBM] [Info] Start training from score -1.791216
# [LightGBM] [Info] Start training from score -1.924514
# [LightGBM] [Info] Start training from score -2.009071
# [LightGBM] [Info] Start training from score -1.743436
# [LightGBM] [Info] Start training from score -1.677246
# [LightGBM] [Info] Start training from score -1.653513
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 0.9501187648456056
